# %% [markdown]
# <a href="https://colab.research.google.com/github/rgerraty/mnist_generalization/blob/master/gen_cmnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

import numpy as np
from PIL import Image

import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import grad
from torchvision import transforms
from torchvision import datasets
import torchvision.datasets.utils as dataset_utils
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
import numpy.random as random
import urllib

# %%
trans=transforms.Compose([
    transforms.RandomCrop(28, padding=2),
    #transforms.RandomHorizontalFlip(),    
    transforms.RandomRotation(2)])
from six.moves import urllib
opener = urllib.request.build_opener()
opener.addheaders = [('User-agent', 'Mozilla/5.0')]
urllib.request.install_opener(opener)



train_mnist = datasets.mnist.MNIST('./data', train=True, download=True)#,transform=trans)
test_mnist = datasets.mnist.MNIST('./data',train=False, download=True)#,transform=trans)

# %%
train_mnist
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: ./data
#     Split: Train

# %%
def color_grayscale_arr(arr, dc=[0,0,225],bc=[250,122,0]):
  """Converts grayscale imae to either red or green"""
  assert arr.ndim == 2
  dtype = arr.dtype
  h, w = arr.shape
  dc=np.array(dc,ndmin=3).transpose()
  bc=np.array(bc,ndmin=3).transpose()
  arr = np.reshape(arr, [1,w, h])
  arr=np.repeat(arr,repeats=3,axis=0)
  arr=(arr>0)*dc

  #arr=arr+((arr==0)*bc)
  return arr

# %%
train_set=[]
id_test_set=[]
od_test_set=[]
#need to add digit and bg colors values for train set
n_train_cols=1
dc_train=random.randint(0,256,(10,3,n_train_cols))
bc_train=random.randint(0,256,(10,3,n_train_cols))
rand_dig=np.array([1,3,5,7,9])#random.randint(0,9,9)

for idx, (im, label) in enumerate(train_mnist):
      if idx % 10000 == 0:
        print(f'Converting image {idx}/{len(train_mnist)}')
      im_array = np.array(im)
      rand_bin=random.randint(0,n_train_cols)
      colored_arr=color_grayscale_arr(im_array,dc=dc_train[label,:,rand_bin],bc=bc_train[label,:,rand_bin])
      colored_arr=colored_arr.astype(np.uint8)

      train_set.append((colored_arr,label))

      dc_train_tmp=random.randint(0,256,(10,3,1))
      bc_train_tmp=random.randint(0,256,(10,3,1))
      #dc_train[rand_dig,:,:]=dc_train_tmp[rand_dig,:,:]
      #bc_train[rand_dig,:,:]=bc_train_tmp[rand_dig,:,:]


for idx, (im, label) in enumerate(test_mnist):
      if idx % 10000 == 0:
        print(f'Converting image {idx}/{len(test_mnist)}')
      im_array = np.array(im)
      rand_bin=random.randint(0,n_train_cols)
      colored_arr=color_grayscale_arr(im_array,dc=dc_train[label,:,rand_bin],bc=bc_train[label,:,rand_bin])
      colored_arr=colored_arr.astype(np.uint8)

      id_test_set.append((colored_arr,label))

      dc_train_tmp=random.randint(0,256,(10,3,1))
      bc_train_tmp=random.randint(0,256,(10,3,1))
      #dc_train[rand_dig,:,:]=dc_train_tmp[rand_dig,:,:]
      #bc_train[rand_dig,:,:]=bc_train_tmp[rand_dig,:,:]

for idx, (im, label) in enumerate(test_mnist):      
      if idx % 10000 == 0:
        print(f'Converting image {idx}/{len(test_mnist)}')
      im_array=np.array(im)
      colored_arr=color_grayscale_arr(im_array,dc=random.randint(0,255,3),bc=random.randint(0,255,3))
      colored_arr=colored_arr.astype(np.uint8)
      #test_set.append((Image.fromarray(colored_arr),label))
      od_test_set.append((colored_arr,label))
# Out:
# Converting image 0/60000
# Converting image 10000/60000
# Converting image 20000/60000
# Converting image 30000/60000
# Converting image 40000/60000
# Converting image 50000/60000
# Converting image 0/10000
# Converting image 0/10000

# %%
from torchvision.utils import make_grid, save_image
import matplotlib.pyplot as plt
batch_size = 25

train_loader=DataLoader(train_set,batch_size=batch_size,shuffle=True)
batch = next(iter(train_loader))
images = batch[0]
labels = batch[1]
im_size=images.shape[3]
grid = make_grid(images, nrow=np.int(batch_size/5))
#save_image(images, 'stl.png', nrow=12)
plt.figure(figsize=(20,10))
plt.imshow(grid.permute(1,2,0))

# %%
from torchvision.utils import make_grid, save_image
import matplotlib.pyplot as plt
batch_size = 25


train_loader=DataLoader(train_set,batch_size=batch_size,shuffle=True)
od_test_loader=DataLoader(od_test_set,batch_size=batch_size,shuffle=True)
batch = next(iter(od_test_loader))
images = batch[0]
labels = batch[1]
im_size=images.shape[3]
grid = make_grid(images, np.int(batch_size/5))
#save_image(images, 'stl.png', nrow=12)
plt.figure(figsize=(20,10))
plt.imshow(grid.permute(1,2,0))

# %%
class b_net(nn.Module):
  def __init__(self,im_size=28,z_dim=50):
    super(b_net,self).__init__()
    self.relu=nn.ReLU()
    self.conv1=nn.Sequential(nn.Conv2d(3,32,kernel_size=3,stride=1,padding=1),
                                     nn.BatchNorm2d(32))
    self.conv1_relu_mp=nn.Sequential(nn.ReLU(),
                                    nn.MaxPool2d(2))
    
    self.conv2=nn.Sequential(nn.Conv2d(32,32,3,1,1),
                                     nn.BatchNorm2d(32))
    self.conv2_relu_mp=nn.Sequential(nn.ReLU(),
                                     nn.MaxPool2d(2))
    
    self.conv3=nn.Sequential(nn.Conv2d(32,64,3,1,1),
                                     nn.BatchNorm2d(64))
    self.conv3_relu_mp=nn.Sequential(nn.ReLU(),
                                     nn.MaxPool2d(2))
    
    self.fc=nn.Sequential(nn.Linear(3*3*64,z_dim),
                          nn.ReLU())

    self.logits=nn.Linear(z_dim,10)
  
  def forward(self,image,dropp=0):
    conv1=self.conv1(image)
    conv1_relu_mp=self.conv1_relu_mp(conv1)
    conv2=self.conv2(conv1_relu_mp)
    conv2_relu_mp=self.conv2_relu_mp(conv2)
    conv3=self.conv3(conv2_relu_mp)
    conv3_relu_mp=self.conv3_relu_mp(conv3)
    fc=nn.functional.dropout(self.fc(conv3_relu_mp.view(-1,3*3*64)),
                                p=dropp,training=self.training)
    #discrim_fc=self.relu(self.discrim_fc(fc))
    logits=nn.functional.dropout(self.logits(fc),p=dropp,training=self.training)
    logits=self.logits(fc)
    #softmax=self.softmax(fc)

    return logits

# %%
def create_z_sample(z_mu,z_logsigma,n_samps=1):
    z_sample=0
    z_sigma = torch.exp(z_logsigma)
    eps = torch.randn_like(z_sigma)
    for i in range(n_samps):
      z_sample += eps.mul(z_sigma).add_(z_mu)
    z_sample/=n_samps
    return z_sample


def kl_div_norm(mu1, logsigma1, mu2, logsigma2):
  # KL( N(mu_1, sigma2_1) || N(mu_2, sigma2_2)) = 
  # 
  sigma1 = logsigma1.exp() 
  sigma2=np.exp(logsigma2)
  kld = torch.log(sigma2/sigma1) + (sigma1**2 + (mu1 - mu2)**2)/(2*(sigma2**2)) - 1/2
  return kld.sum()

import math
def get_conv_out_size(W=64,K=4,P=0,S=2):
  o_s=math.floor(((W-K+2*P)/S)+1)
  return o_s

# %%
class vb_net(nn.Module):
  def __init__(self,z_dim=20,n_samps=1,im_size=28):
    super(vb_net,self).__init__()
    self.relu=nn.ReLU()

    self.conv1=nn.Sequential(nn.Conv2d(3,32,3,stride=1,padding=1),
                             nn.BatchNorm2d(32)
                             )
    self.conv1_relu_mp=nn.MaxPool2d(2,return_indices=True)
    self.conv1_size=self.conv1_relu_mp(self.conv1(torch.randn(1,3,im_size,im_size)))[0].size()

    

    self.conv2=nn.Sequential(nn.Conv2d(32,32,3,1,1),
                             nn.BatchNorm2d(32)
                             )
    self.conv2_relu_mp=nn.MaxPool2d(2,return_indices=True)
    self.conv2_size=self.conv2_relu_mp(self.conv2(torch.randn(1,self.conv1_size[1],self.conv1_size[2],self.conv1_size[3])))[0].size()

    

    self.conv3=nn.Sequential(nn.Conv2d(32,64,3,1,1),
                             nn.BatchNorm2d(64)
                             )
    self.conv3_relu_mp=nn.MaxPool2d(2,return_indices=True)
    

    self.fc=nn.Sequential(nn.Linear(3*3*64,z_dim),
                          nn.ReLU())
    
    self.z_mu=nn.Linear(z_dim,z_dim)
    self.z_logsigma=nn.Linear(z_dim,z_dim)
    #self.discrim_fc=nn.Linear(z_dim,10)
    self.logits=nn.Linear(z_dim,10)
    #self.softmax=nn.Softmax()

    self.fc2=nn.Sequential(nn.Linear(z_dim,3*3*64),
                           nn.ReLU())
    
    self.bnfc=nn.BatchNorm2d(64)
    
    self.dconv1_unp=nn.Upsample(size=self.conv2_size[2:],mode='nearest')
    self.dconv1=nn.Sequential(nn.Conv2d(64,32,3,1,1),
                              nn.BatchNorm2d(32)
    )

    self.dconv2_unp=nn.Upsample(scale_factor=2,mode='nearest')
    self.dconv2=nn.Sequential(nn.Conv2d(32,32,3,1,1),
                              nn.BatchNorm2d(32)
    )

    self.dconv3_unp=nn.Upsample(scale_factor=2,mode='nearest')
    self.dconv3=nn.Sequential(nn.Conv2d(32,3,3,1,1),
                              #nn.BatchNorm2d(3),
                              nn.Sigmoid())
    
    
  def forward(self,image,validation=False,dropp=0.0):
    conv1=self.conv1(image)
    max1_size = conv1.size()
    conv1_relu_mp,indices1=self.conv1_relu_mp(self.relu(conv1))

    conv2=self.conv2(conv1_relu_mp)
    max2_size = conv2.size()
    conv2_relu_mp,indices2=self.conv2_relu_mp(self.relu(conv2))

    conv3=self.conv3(conv2_relu_mp)
    max3_size = conv3.size()
    conv3_relu_mp,indices3=self.conv3_relu_mp(self.relu(conv3))

    fc=nn.functional.dropout(self.fc(conv3_relu_mp.view(-1,3*3*64)),
                                p=dropp,training=self.training)

    z_mu=self.z_mu(fc)
    z_logsigma=self.z_logsigma(fc)
    if not validation:
      z_samp=create_z_sample(z_mu,z_logsigma)
    else:
      z_samp=z_mu
    #discrim_fc=self.relu(self.discrim_fc(z_samp))
    #logits=nn.functional.dropout(self.logits(z_samp),
     #                            p=dropp,training=self.training)
    logits=self.logits(z_samp)

    kl_div=kl_div_norm(z_mu,z_logsigma,0,0)

    #fc2=self.fc2(z_samp)
    fc2=nn.functional.dropout(self.fc2(z_samp),
                                 p=dropp,training=self.training)
    fc2=self.bnfc(fc2.view(-1,64,3,3))

    dconv1_unp=self.dconv1_unp(fc2)
    dconv1=self.relu(self.dconv1(dconv1_unp))

    dconv2_unp=self.dconv2_unp(dconv1)
    dconv2=self.relu(self.dconv2(dconv2_unp))

    dconv3_unp=self.dconv3_unp(dconv2)
    dconv3=self.dconv3(dconv3_unp)
    
    return dconv3,logits,kl_div

# %%
class Recon_loss(nn.Module):
  def __init__(self):
    super(Recon_loss,self).__init__()
    self.loss=nn.BCELoss(reduction='sum')
    #self.loss=lambda rec_x,x:torch.sum(torch.abs(rec_x-x))
  def forward(self,recon_x,image):
    recon_loss=self.loss(recon_x,image)
    return recon_loss

# %%
class ivb_net(nn.Module):
  def __init__(self,z_dim=20,n_samps=1,im_size=28):
    super(ivb_net,self).__init__()
    self.relu=nn.ReLU()
    self.recon_loss=Recon_loss()
    self.logit_loss=nn.CrossEntropyLoss(reduction='sum')

    self.conv1=nn.Sequential(nn.Conv2d(3,32,3,stride=1,padding=1),
                             nn.BatchNorm2d(32)
                             )
    self.conv1_relu_mp=nn.MaxPool2d(2,return_indices=True)
    self.conv1_size=self.conv1_relu_mp(self.conv1(torch.randn(1,3,im_size,im_size)))[0].size()

    

    self.conv2=nn.Sequential(nn.Conv2d(32,32,3,1,1),
                             nn.BatchNorm2d(32)
                             )
    self.conv2_relu_mp=nn.MaxPool2d(2,return_indices=True)
    self.conv2_size=self.conv2_relu_mp(self.conv2(torch.randn(1,self.conv1_size[1],self.conv1_size[2],self.conv1_size[3])))[0].size()

    

    self.conv3=nn.Sequential(nn.Conv2d(32,64,3,1,1),
                             nn.BatchNorm2d(64)
                             )
    self.conv3_relu_mp=nn.MaxPool2d(2,return_indices=True)
    

    self.fc=nn.Sequential(nn.Linear(3*3*64,z_dim),
                          nn.ReLU())
    
    self.z_mu=nn.Linear(z_dim,z_dim)
    self.z_logsigma=nn.Linear(z_dim,z_dim)

    self.z_mu_update=nn.Linear(z_dim,z_dim)
    self.z_logsigma_update=nn.Linear(z_dim,z_dim)

    #self.discrim_fc=nn.Linear(z_dim,10)
    self.logits=nn.Linear(z_dim,10)
    #self.softmax=nn.Softmax()

    

    self.fc2=nn.Sequential(nn.Linear(z_dim,3*3*64),
                           nn.ReLU())
    
    self.bnfc=nn.BatchNorm2d(64)
    
    self.dconv1_unp=nn.Upsample(size=self.conv2_size[2:],mode='nearest')
    self.dconv1=nn.Sequential(nn.Conv2d(64,32,3,1,1),
                              nn.BatchNorm2d(32)
    )

    self.dconv2_unp=nn.Upsample(scale_factor=2,mode='nearest')
    self.dconv2=nn.Sequential(nn.Conv2d(32,32,3,1,1),
                              nn.BatchNorm2d(32)
    )

    self.dconv3_unp=nn.Upsample(scale_factor=2,mode='nearest')
    self.dconv3=nn.Sequential(nn.Conv2d(32,3,3,1,1),
                              #nn.BatchNorm2d(3),
                              nn.Sigmoid())
    
    
  def forward(self,image,labels=labels,validation=False,iterations=15,dropp=0):
    kl_div=0
    kl_div_old=0
    recon_loss_old=0
    kl_div_new=0
    recon_loss_new=0
    recon_loss=0
    logit_loss_old=0
    logit_loss_new=0
    logit_loss=0
    error_x=image
    for i in range(iterations):

      conv1=self.conv1(error_x)

      max1_size = conv1.size()
      conv1_relu_mp,indices1=self.conv1_relu_mp(self.relu(conv1))

      conv2=self.conv2(conv1_relu_mp)
      max2_size = conv2.size()
      conv2_relu_mp,indices2=self.conv2_relu_mp(self.relu(conv2))

      conv3=self.conv3(conv2_relu_mp)
      max3_size = conv3.size()
      conv3_relu_mp,indices3=self.conv3_relu_mp(self.relu(conv3))

      fc=nn.functional.dropout(self.fc(conv3_relu_mp.view(-1,3*3*64)),
                                       p=dropp,training=self.training)

      
      if i>0:
        #z_mu+=self.z_mu_error(error_z)
        z_mu=self.z_mu(fc)+self.z_mu_update(z_mu)
        #z_logsigma+=self.z_logsigma_error(error_z)
        z_logsigma=self.z_logsigma(fc)+self.z_logsigma_update(z_logsigma)

      else:
        z_mu=self.z_mu(fc)
        #z_mu+=self.z_mu_update(torch.zeros_like(z_mu))
        z_logsigma=self.z_logsigma(fc)
        #z_logsigma+=self.z_logsigma_update(torch.zeros_like(z_logsigma))
    
      if not validation:
        z_samp=create_z_sample(z_mu,z_logsigma)
      else:
        z_samp=z_mu
      #discrim_fc=self.relu(self.discrim_fc(z_samp))
      

      

      #fc2=self.fc2(z_samp)
      fc2=nn.functional.dropout(self.fc2(z_samp),
                                       p=dropp,training=self.training)
      fc2=self.bnfc(fc2.view(-1,64,3,3))

      dconv1_unp=self.dconv1_unp(fc2)
      dconv1=self.relu(self.dconv1(dconv1_unp))

      dconv2_unp=self.dconv2_unp(dconv1)
      dconv2=self.relu(self.dconv2(dconv2_unp))

      dconv3_unp=self.dconv3_unp(dconv2)
      dconv3=self.dconv3(dconv3_unp)

      error_x=image-dconv3
      #error_z=z_samp
      
      kl_div_new=kl_div_norm(z_mu,z_logsigma,0,0)
      #kl_div+=(kl_div_new-kl_div_old)
      #
      kl_div+=(kl_div_new-kl_div_old)*np.exp(-.2*i)
      kl_div_old=kl_div_new

      recon_loss_new=self.recon_loss(dconv3,image)
      #recon_loss+=(recon_loss_new-recon_loss_old)
      
      recon_loss+=(recon_loss_new-recon_loss_old)*np.exp(-.2*i)
      recon_loss_old=recon_loss_new

      logits=self.logits(z_samp)
      logit_loss_new=self.logit_loss(logits,labels)
      #logit_loss+=(logit_loss_new-logit_loss_old)
      #
      logit_loss+=(logit_loss_new-logit_loss_old)*np.exp(-.2*i)
      logit_loss_old=logit_loss_new

      recon_loss+=logit_loss
    
    #logits=nn.functional.dropout(self.logits(z_samp),p=dropp,training=self.training)
    
    return dconv3,logits,kl_div,recon_loss

# %%
class ivb2_net(nn.Module):
  def __init__(self,z_dim=20,n_samps=1,im_size=28):
    super(ivb2_net,self).__init__()
    self.relu=nn.ReLU()
    self.recon_loss=Recon_loss()
    self.logit_loss=nn.CrossEntropyLoss(reduction='sum')

    self.conv1=nn.Sequential(nn.Conv2d(3,32,3,stride=1,padding=1),
                             nn.BatchNorm2d(32)
                             )
    self.conv1_relu_mp=nn.MaxPool2d(2,return_indices=True)
    self.conv1_size=self.conv1_relu_mp(self.conv1(torch.randn(1,3,im_size,im_size)))[0].size()

    

    self.conv2=nn.Sequential(nn.Conv2d(32,32,3,1,1),
                             nn.BatchNorm2d(32)
                             )
    self.conv2_relu_mp=nn.MaxPool2d(2,return_indices=True)
    self.conv2_size=self.conv2_relu_mp(self.conv2(torch.randn(1,self.conv1_size[1],self.conv1_size[2],self.conv1_size[3])))[0].size()

    

    self.conv3=nn.Sequential(nn.Conv2d(32,64,3,1,1),
                             nn.BatchNorm2d(64)
                             )
    self.conv3_relu_mp=nn.MaxPool2d(2,return_indices=True)
    

    self.fc=nn.Sequential(nn.Linear(3*3*64,z_dim),
                          nn.ReLU())
    
    self.z_mu=nn.Linear(z_dim,z_dim)
    self.z_logsigma=nn.Linear(z_dim,z_dim)


    self.conv1_update=nn.Sequential(nn.Conv2d(3,32,3,stride=1,padding=1),
                             nn.BatchNorm2d(32)
                             )
    self.conv1_relu_mp_update=nn.MaxPool2d(2,return_indices=True)
    self.conv1_size_update=self.conv1_relu_mp(self.conv1(torch.randn(1,3,im_size,im_size)))[0].size()

    

    self.conv2_update=nn.Sequential(nn.Conv2d(32,32,3,1,1),
                             nn.BatchNorm2d(32)
                             )
    self.conv2_relu_mp_update=nn.MaxPool2d(2,return_indices=True)
    self.conv2_size_update=self.conv2_relu_mp(self.conv2(torch.randn(1,self.conv1_size[1],self.conv1_size[2],self.conv1_size[3])))[0].size()

    

    self.conv3_update=nn.Sequential(nn.Conv2d(32,64,3,1,1),
                             nn.BatchNorm2d(64)
                             )
    self.conv3_relu_mp_update=nn.MaxPool2d(2,return_indices=True)
    

    self.fc_update=nn.Sequential(nn.Linear(3*3*64,z_dim),
                          nn.ReLU())
    
    self.z_mu_update=nn.Linear(z_dim,z_dim)
    self.z_logsigma_update=nn.Linear(z_dim,z_dim)

    #self.discrim_fc=nn.Linear(z_dim,10)
    self.logits=nn.Linear(z_dim,10)
    #self.softmax=nn.Softmax()

    

    self.fc2=nn.Sequential(nn.Linear(z_dim,3*3*64),
                           nn.ReLU())
    
    self.bnfc=nn.BatchNorm2d(64)
    
    self.dconv1_unp=nn.Upsample(size=self.conv2_size[2:],mode='nearest')
    self.dconv1=nn.Sequential(nn.Conv2d(64,32,3,1,1),
                              nn.BatchNorm2d(32)
    )

    self.dconv2_unp=nn.Upsample(scale_factor=2,mode='nearest')
    self.dconv2=nn.Sequential(nn.Conv2d(32,32,3,1,1),
                              nn.BatchNorm2d(32)
    )

    self.dconv3_unp=nn.Upsample(scale_factor=2,mode='nearest')
    self.dconv3=nn.Sequential(nn.Conv2d(32,3,3,1,1),
                              #nn.BatchNorm2d(3),
                              nn.Sigmoid())
    
    
  def forward(self,image,labels=labels,validation=False,iterations=15,dropp=0):
    kl_div=0
    kl_div_old=0
    recon_loss_old=0
    kl_div_new=0
    recon_loss_new=0
    recon_loss=0
    logit_loss_old=0
    logit_loss_new=0
    logit_loss=0

    for i in range(iterations):

      

      
      if i==0:
        conv1=self.conv1(image)

        max1_size = conv1.size()
        conv1_relu_mp,indices1=self.conv1_relu_mp(self.relu(conv1))

        conv2=self.conv2(conv1_relu_mp)
        max2_size = conv2.size()
        conv2_relu_mp,indices2=self.conv2_relu_mp(self.relu(conv2))

        conv3=self.conv3(conv2_relu_mp)
        max3_size = conv3.size()
        conv3_relu_mp,indices3=self.conv3_relu_mp(self.relu(conv3))

        fc=nn.functional.dropout(self.fc(conv3_relu_mp.view(-1,3*3*64)),
                                       p=dropp,training=self.training)
        #z_mu+=self.z_mu_error(error_z)
        z_mu=self.z_mu(fc)
        #z_logsigma+=self.z_logsigma_error(error_z)
        z_logsigma=self.z_logsigma(fc)

      else:
        conv1=self.conv1_update(error_x)

        max1_size = conv1.size()
        conv1_relu_mp,indices1=self.conv1_relu_mp(self.relu(conv1))

        conv2=self.conv2_update(conv1_relu_mp)
        max2_size = conv2.size()
        conv2_relu_mp,indices2=self.conv2_relu_mp_update(self.relu(conv2))

        conv3=self.conv3_update(conv2_relu_mp)
        max3_size = conv3.size()
        conv3_relu_mp,indices3=self.conv3_relu_mp_update(self.relu(conv3))

        fc=nn.functional.dropout(self.fc_update(conv3_relu_mp.view(-1,3*3*64)),
                                       p=dropp,training=self.training)
        z_mu=z_mu+self.z_mu_update(fc)
        #z_mu+=self.z_mu_update(torch.zeros_like(z_mu))
        z_logsigma=z_logsigma+self.z_logsigma_update(fc)
        #z_logsigma+=self.z_logsigma_update(torch.zeros_like(z_logsigma))
    
      if not validation:
        z_samp=create_z_sample(z_mu,z_logsigma)
      else:
        z_samp=z_mu
      #discrim_fc=self.relu(self.discrim_fc(z_samp))
      

      

      #fc2=self.fc2(z_samp)
      fc2=nn.functional.dropout(self.fc2(z_samp),
                                       p=dropp,training=self.training)
      fc2=self.bnfc(fc2.view(-1,64,3,3))

      dconv1_unp=self.dconv1_unp(fc2)
      dconv1=self.relu(self.dconv1(dconv1_unp))

      dconv2_unp=self.dconv2_unp(dconv1)
      dconv2=self.relu(self.dconv2(dconv2_unp))

      dconv3_unp=self.dconv3_unp(dconv2)
      dconv3=self.dconv3(dconv3_unp)

      error_x=image-dconv3
      #error_z=z_samp
      
      kl_div_new=kl_div_norm(z_mu,z_logsigma,0,0)
      #kl_div+=(kl_div_new-kl_div_old)
      #
      kl_div+=(kl_div_new-kl_div_old)*np.exp(-.1*i)
      kl_div_old=kl_div_new

      recon_loss_new=self.recon_loss(dconv3,image)
      #recon_loss+=(recon_loss_new-recon_loss_old)
      
      recon_loss+=(recon_loss_new-recon_loss_old)*np.exp(-.1*i)
      recon_loss_old=recon_loss_new

      logits=self.logits(z_samp)
      logit_loss_new=self.logit_loss(logits,labels)
      #logit_loss+=(logit_loss_new-logit_loss_old)
      #
      logit_loss+=(logit_loss_new-logit_loss_old)*np.exp(-.1*i)
      logit_loss_old=logit_loss_new

      recon_loss+=logit_loss
    
    #logits=nn.functional.dropout(self.logits(z_samp),p=dropp,training=self.training)
    
    return dconv3,logits,kl_div,recon_loss

# %%
class rvbt_net(nn.Module):
  def __init__(self,z_dim=20,n_samps=1,im_size=28):
    super(rvbt_net,self).__init__()
    self.relu=nn.ReLU()
    self.recon_loss=Recon_loss()

    self.conv1=nn.Sequential(nn.Conv2d(3,32,3,stride=1,padding=1),
                             nn.BatchNorm2d(32)
                             )
    self.conv1_relu_mp=nn.MaxPool2d(2,return_indices=True)
    self.conv1_size=self.conv1_relu_mp(self.conv1(torch.randn(1,3,im_size,im_size)))[0].size()

    

    self.conv2=nn.Sequential(nn.Conv2d(32,32,3,1,1),
                             nn.BatchNorm2d(32)
                             )
    self.conv2_relu_mp=nn.MaxPool2d(2,return_indices=True)
    self.conv2_size=self.conv2_relu_mp(self.conv2(torch.randn(1,self.conv1_size[1],self.conv1_size[2],self.conv1_size[3])))[0].size()

    

    self.conv3=nn.Sequential(nn.Conv2d(32,64,3,1,1),
                             nn.BatchNorm2d(64)
                             )
    self.conv3_relu_mp=nn.MaxPool2d(2,return_indices=True)
    

    self.fc=nn.Sequential(nn.Linear(3*3*64,z_dim),
                          nn.ReLU())
    
    self.z_mu=nn.Linear(z_dim,z_dim)
    self.z_logsigma=nn.Linear(z_dim,z_dim)

    #self.z_mu_error=nn.Linear(z_dim,z_dim)
    self.z_mu_current=nn.Linear(z_dim,z_dim)
    #self.z_logsigma_error=nn.Linear(z_dim,z_dim)
    self.z_logsigma_current=nn.Linear(z_dim,z_dim)

    #self.discrim_fc=nn.Linear(z_dim,10)
    self.logits=nn.Linear(z_dim,10)
    #self.softmax=nn.Softmax()

    

    self.fc2=nn.Sequential(nn.Linear(z_dim,3*3*64),
                           nn.ReLU())
    
    self.bnfc=nn.BatchNorm2d(64)
    
    self.dconv1_unp=nn.Upsample(size=self.conv2_size[2:],mode='nearest')
    self.dconv1=nn.Sequential(nn.Conv2d(64,32,3,1,1),
                              nn.BatchNorm2d(32)
    )

    self.dconv2_unp=nn.Upsample(scale_factor=2,mode='nearest')
    self.dconv2=nn.Sequential(nn.Conv2d(32,32,3,1,1),
                              nn.BatchNorm2d(32)
    )

    self.dconv3_unp=nn.Upsample(scale_factor=2,mode='nearest')
    self.dconv3=nn.Sequential(nn.Conv2d(32,3,3,1,1),
                              nn.BatchNorm2d(3),
                              nn.Sigmoid())
    
    
  def forward(self,image,validation=True,iterations=10):
    kl_div=0
    recon_loss=0
    error_x=image
    for i in range(iterations):

      conv1=self.conv1(error_x)

      max1_size = conv1.size()
      conv1_relu_mp,indices1=self.conv1_relu_mp(self.relu(conv1))

      conv2=self.conv2(conv1_relu_mp)
      max2_size = conv2.size()
      conv2_relu_mp,indices2=self.conv2_relu_mp(self.relu(conv2))

      conv3=self.conv3(conv2_relu_mp)
      max3_size = conv3.size()
      conv3_relu_mp,indices3=self.conv3_relu_mp(self.relu(conv3))

      fc=self.fc(conv3_relu_mp.view(-1,3*3*64))

      
      if i>0:
        #z_mu+=self.z_mu_error(error_z)
        z_mu=self.z_mu(fc)+self.z_mu_current(z_mu)
        #z_logsigma+=self.z_logsigma_error(error_z)
        z_logsigma=self.z_logsigma(fc)+self.z_logsigma_current(z_logsigma)

      else:
        z_mu=self.z_mu(fc)
        z_mu+=self.z_mu_current(torch.zeros_like(z_mu))
        z_logsigma=self.z_logsigma(fc)
        z_logsigma+=self.z_logsigma_current(torch.zeros_like(z_logsigma))
    
      if not validation:
        z_samp=create_z_sample(z_mu,z_logsigma)
      else:
        z_samp=z_mu
      #discrim_fc=self.relu(self.discrim_fc(z_samp))
      

      

      fc2=self.fc2(z_samp)
      fc2=self.bnfc(fc2.view(-1,64,3,3))

      dconv1_unp=self.dconv1_unp(fc2)
      dconv1=self.relu(self.dconv1(dconv1_unp))

      dconv2_unp=self.dconv2_unp(dconv1)
      dconv2=self.relu(self.dconv2(dconv2_unp))

      dconv3_unp=self.dconv3_unp(dconv2)
      dconv3=self.dconv3(dconv3_unp)

      error_x=image-dconv3
      #error_z=z_samp
      kl_div+=(kl_div_norm(z_mu,z_logsigma,0,0)-kl_div)
      recon_loss+=(self.recon_loss(dconv3,image)-recon_loss)
    
    logits=self.logits(z_samp)
    
    return dconv3,logits,kl_div,recon_loss

# %%
class label_loss(nn.Module):
  def __init__(self):
    super(label_loss,self).__init__()
    self.loss=nn.CrossEntropyLoss(reduction='sum')
  def forward(self,softmax,label,recon_loss=0,kl_loss=0,tau=1,beta=1):
    loss=self.loss(softmax,label)
    return (tau*loss)+recon_loss+beta*kl_loss

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
batch_size=25
model=ivb2_net(z_dim=50).to(device)
loss_=label_loss()
recon_loss_=Recon_loss()
optimizer=torch.optim.Adam(model.parameters(),lr=0.0001)

if 0: 
  for name,param in model.named_parameters():
    if name=='conv1.weight' or name=='conv1.bias':
      param.requires_grad=False
  optimizer=torch.optim.Adam(filter(lambda p: p.requires_grad, model.parameters()),lr=1e-3)


train_loader=DataLoader(train_set,batch_size=batch_size,shuffle=True)
id_test_loader=DataLoader(id_test_set,batch_size=batch_size,shuffle=True)
od_test_loader=DataLoader(od_test_set,batch_size=batch_size,shuffle=True)

# %%
seed = 0

train_loss = []
train_acc=[]
id_test_loss = []
id_test_acc = []
od_test_loss = []
od_test_acc = []
#test_label=[]
beta=1

# %%
def train(batch,epoch,train_size):
  x=batch[0].float().to(device)/255
  model.train()
  kl_loss=0
  recon_loss=0
  acc=0
  loss=0
  model.zero_grad()
  optimizer.zero_grad()
  label_ind=batch[1].to(device)
  label=torch.eye(10)[label_ind].to(device) 

  if model._get_name()=='b_net':
    logits=model(x)
    recon=0
  elif model._get_name()=='vb_net' or model._get_name()=='hvb_net':
    recon,logits,kl_loss=model(x,validation=False)
    recon_loss=recon_loss_(recon,x)
  elif model._get_name()=='ivb_net' or model._get_name()=='ivb2_net':
    recon,logits,kl_loss,recon_loss=model(x,label_ind,validation=False)
   

  pred_lab=np.argmax(np.exp(logits.to('cpu').detach()),1)
  
  
  loss=loss_(logits,label_ind,recon_loss=recon_loss,kl_loss=kl_loss,tau=tau,beta=beta)
    
   
  acc=torch.sum((label_ind==pred_lab.to(device))+0).to('cpu').numpy()
  acc=acc/train_size
  
  loss.backward()
  optimizer.step()
  loss=loss/train_size
  
  return x,label,pred_lab,recon,logits,acc,loss

# %%
def test(batch,epoch,test_size):
  x=batch[0].float().to(device)/255
  loss=0
  kl_loss=0
  recon_loss=0
  acc=0
  with torch.no_grad():
    label_ind=batch[1].to(device)
    label=torch.eye(10)[label_ind].to(device)  
    if model._get_name()=='b_net':
      logits=model(x)
      recon=0
    elif model._get_name()=='vb_net' or model._get_name()=='hvb_net':
      recon,logits,kl_loss=model(x,validation=True)
      recon_loss=recon_loss_(recon,x)
    elif model._get_name()=='ivb_net' or model._get_name()=='ivb2_net':
      recon,logits,kl_loss,recon_loss=model(x,label_ind,validation=True)
      

    pred_lab=np.argmax(np.exp(logits.to('cpu').detach()),1)
  
    loss=loss_(logits,label_ind,recon_loss=recon_loss,kl_loss=kl_loss,tau=tau,beta=beta)
    loss=loss/test_size
    acc=torch.sum((label_ind==pred_lab.to(device))+0).to('cpu').numpy()
    acc=acc/test_size

    
  
  return(x,label,pred_lab,recon,logits,acc,loss)

# %%
tau=1
beta=1
n_iter=np.int(np.floor(len(train_loader.dataset)/train_loader.batch_size))
num_steps=200
num_epochs=30
for i in range(num_epochs-1):
  train_loader=DataLoader(train_set,batch_size=batch_size,shuffle=True)
  id_test_loader=DataLoader(id_test_set,batch_size=batch_size,shuffle=True)
  od_test_loader=DataLoader(od_test_set,batch_size=batch_size,shuffle=True)
  it_train=iter(train_loader)
  it_test_id=iter(id_test_loader)
  it_test_od=iter(od_test_loader)
  tr_acc=0
  tr_loss=0
  for j in range(n_iter):

    data=next(it_train)
    x,label,pred_lab,recon,logits,acc,loss=train(data,i,batch_size)
    tr_acc+=acc/num_steps
    tr_loss+=loss/num_steps

    if (j % num_steps)==0 and (j>0):
      train_acc.append(np.float16(tr_acc))
      train_loss.append(np.float16(tr_loss.cpu().detach().numpy()))
      print('====> Epoch: {} Average loss: {:.4f} Accuracy: {:.2f} '.format(i, loss,acc))

      data=next(it_test_id)
      x,label,pred_lab,recon,logits,acc,loss=test(data,i,batch_size)
      print('====> Epoch: {} ID Test set loss: {:.4f} Accuracy: {:.2f} '.format(i, loss,acc))
      id_test_loss.append(np.float16(loss.cpu().detach().numpy()))
      id_test_acc.append(np.float16(acc))

      data=next(it_test_od)
      x,label,pred_lab,recon,logits,acc,loss=test(data,i,batch_size)
      print('====> Epoch: {} OD Test set loss: {:.4f} Accuracy: {:.2f} '.format(i, loss,acc))
      od_test_loss.append(np.float16(loss.cpu().detach().numpy()))
      od_test_acc.append(np.float16(acc))
      tr_acc=0
      tr_loss=0
      #test_label.append(label)
    
  beta=1/(i+1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: RuntimeWarning: overflow encountered in exp
# ====> Epoch: 0 Average loss: 229122.8750 Accuracy: 0.12
# ====> Epoch: 0 ID Test set loss: 167902672.0000 Accuracy: 0.12
# ====> Epoch: 0 OD Test set loss: 167675.5312 Accuracy: 0.12
# ====> Epoch: 0 Average loss: 46680.3008 Accuracy: 0.12
# ====> Epoch: 0 ID Test set loss: 251776.2969 Accuracy: 0.16
# ====> Epoch: 0 OD Test set loss: 131983.2812 Accuracy: 0.16
# ====> Epoch: 0 Average loss: 27117.7148 Accuracy: 0.04
# ====> Epoch: 0 ID Test set loss: 87850.8359 Accuracy: 0.04
# ====> Epoch: 0 OD Test set loss: 543651.0625 Accuracy: 0.08
# ====> Epoch: 0 Average loss: 19695.1934 Accuracy: 0.20
# ====> Epoch: 0 ID Test set loss: 69466.6250 Accuracy: 0.16
# ====> Epoch: 0 OD Test set loss: 122932.2266 Accuracy: 0.12
# ====> Epoch: 0 Average loss: 7872.5854 Accuracy: 0.12
# ====> Epoch: 0 ID Test set loss: 52213.3281 Accuracy: 0.32
# ====> Epoch: 0 OD Test set loss: 161941.3750 Accuracy: 0.12
# ====> Epoch: 0 Average loss: 9569.5557 Accuracy: 0.08
# ====> Epoch: 0 ID Test set loss: 22779.5742 Accuracy: 0.32
# ====> Epoch: 0 OD Test set loss: 85253.7188 Accuracy: 0.16
# ====> Epoch: 0 Average loss: 9585.1777 Accuracy: 0.20
# ====> Epoch: 0 ID Test set loss: 29327.9570 Accuracy: 0.44
# ====> Epoch: 0 OD Test set loss: 34399.9023 Accuracy: 0.16
# ====> Epoch: 0 Average loss: 15801.8145 Accuracy: 0.12
# ====> Epoch: 0 ID Test set loss: 23271.7695 Accuracy: 0.52
# ====> Epoch: 0 OD Test set loss: 22753.8418 Accuracy: 0.16
# ====> Epoch: 0 Average loss: 7743.3784 Accuracy: 0.08
# ====> Epoch: 0 ID Test set loss: 9512.2559 Accuracy: 0.52
# ====> Epoch: 0 OD Test set loss: 79458.0781 Accuracy: 0.12
# ====> Epoch: 0 Average loss: 5852.4180 Accuracy: 0.16
# ====> Epoch: 0 ID Test set loss: 7049.9263 Accuracy: 0.44
# ====> Epoch: 0 OD Test set loss: 20608.7168 Accuracy: 0.20
# ====> Epoch: 0 Average loss: 4056.6375 Accuracy: 0.16
# ====> Epoch: 0 ID Test set loss: 5326.2656 Accuracy: 0.56
# ====> Epoch: 0 OD Test set loss: 59667.7617 Accuracy: 0.16
# ====> Epoch: 1 Average loss: 3046.2305 Accuracy: 0.60
# ====> Epoch: 1 ID Test set loss: 3849.6094 Accuracy: 0.72
# ====> Epoch: 1 OD Test set loss: 9587.6240 Accuracy: 0.32
# ====> Epoch: 1 Average loss: 2790.4478 Accuracy: 0.24
# ====> Epoch: 1 ID Test set loss: 5577.4351 Accuracy: 0.72
# ====> Epoch: 1 OD Test set loss: 8599.8740 Accuracy: 0.16
# ====> Epoch: 1 Average loss: 2548.6931 Accuracy: 0.32
# ====> Epoch: 1 ID Test set loss: 3091.3325 Accuracy: 0.64
# ====> Epoch: 1 OD Test set loss: 42576.7148 Accuracy: 0.04
# ====> Epoch: 1 Average loss: 2456.3274 Accuracy: 0.44
# ====> Epoch: 1 ID Test set loss: 2806.5244 Accuracy: 0.72
# ====> Epoch: 1 OD Test set loss: 4015.6296 Accuracy: 0.12
# ====> Epoch: 1 Average loss: 2413.3040 Accuracy: 0.52
# ====> Epoch: 1 ID Test set loss: 2946.3604 Accuracy: 0.76
# ====> Epoch: 1 OD Test set loss: 3862.2773 Accuracy: 0.08
# ====> Epoch: 1 Average loss: 2388.7520 Accuracy: 0.44
# ====> Epoch: 1 ID Test set loss: 2266.0977 Accuracy: 0.68
# ====> Epoch: 1 OD Test set loss: 3110.3999 Accuracy: 0.16
# ====> Epoch: 1 Average loss: 2268.3574 Accuracy: 0.48
# ====> Epoch: 1 ID Test set loss: 2386.1553 Accuracy: 0.68
# ====> Epoch: 1 OD Test set loss: 2917.9009 Accuracy: 0.12
# ====> Epoch: 1 Average loss: 2216.0339 Accuracy: 0.44
# ====> Epoch: 1 ID Test set loss: 2351.3745 Accuracy: 0.60
# ====> Epoch: 1 OD Test set loss: 2451.3804 Accuracy: 0.28
# ====> Epoch: 1 Average loss: 2198.9294 Accuracy: 0.60
# ====> Epoch: 1 ID Test set loss: 2516.7666 Accuracy: 0.76
# ====> Epoch: 1 OD Test set loss: 3787.4062 Accuracy: 0.08
# ====> Epoch: 1 Average loss: 2221.4739 Accuracy: 0.60
# ====> Epoch: 1 ID Test set loss: 2240.4585 Accuracy: 0.72
# ====> Epoch: 1 OD Test set loss: 2481.5530 Accuracy: 0.32
# ====> Epoch: 1 Average loss: 2187.2656 Accuracy: 0.64
# ====> Epoch: 1 ID Test set loss: 2208.1919 Accuracy: 0.88
# ====> Epoch: 1 OD Test set loss: 2743.7034 Accuracy: 0.12
# ====> Epoch: 2 Average loss: 1999.9790 Accuracy: 0.84
# ====> Epoch: 2 ID Test set loss: 2034.6884 Accuracy: 0.56
# ====> Epoch: 2 OD Test set loss: 2184.5156 Accuracy: 0.20
# ====> Epoch: 2 Average loss: 2016.0497 Accuracy: 0.60
# ====> Epoch: 2 ID Test set loss: 2012.1040 Accuracy: 0.64
# ====> Epoch: 2 OD Test set loss: 2095.6355 Accuracy: 0.20
# ====> Epoch: 2 Average loss: 2013.3856 Accuracy: 0.64
# ====> Epoch: 2 ID Test set loss: 2093.6672 Accuracy: 0.68
# ====> Epoch: 2 OD Test set loss: 2062.8604 Accuracy: 0.24
# ====> Epoch: 2 Average loss: 1995.1130 Accuracy: 0.64
# ====> Epoch: 2 ID Test set loss: 2006.3906 Accuracy: 0.64
# ====> Epoch: 2 OD Test set loss: 2191.2788 Accuracy: 0.16
# ====> Epoch: 2 Average loss: 2016.6484 Accuracy: 0.72
# ====> Epoch: 2 ID Test set loss: 2036.7992 Accuracy: 0.84
# ====> Epoch: 2 OD Test set loss: 2370.0410 Accuracy: 0.32
# ====> Epoch: 2 Average loss: 1994.1630 Accuracy: 0.64
# ====> Epoch: 2 ID Test set loss: 2009.8669 Accuracy: 0.68
# ====> Epoch: 2 OD Test set loss: 4049.9177 Accuracy: 0.24
# ====> Epoch: 2 Average loss: 2007.0193 Accuracy: 0.76
# ====> Epoch: 2 ID Test set loss: 2007.1185 Accuracy: 0.80
# ====> Epoch: 2 OD Test set loss: 2845.5547 Accuracy: 0.16
# ====> Epoch: 2 Average loss: 2012.4091 Accuracy: 0.72
# ====> Epoch: 2 ID Test set loss: 2017.5193 Accuracy: 0.80
# ====> Epoch: 2 OD Test set loss: 2187.0820 Accuracy: 0.20
# ====> Epoch: 2 Average loss: 1981.1105 Accuracy: 0.92
# ====> Epoch: 2 ID Test set loss: 1986.0045 Accuracy: 0.92
# ====> Epoch: 2 OD Test set loss: 2080.0564 Accuracy: 0.08
# ====> Epoch: 2 Average loss: 1979.1515 Accuracy: 0.60
# ====> Epoch: 2 ID Test set loss: 1985.2753 Accuracy: 0.84
# ====> Epoch: 2 OD Test set loss: 2074.9546 Accuracy: 0.20
# ====> Epoch: 2 Average loss: 1995.9867 Accuracy: 0.64
# ====> Epoch: 2 ID Test set loss: 1982.6406 Accuracy: 0.88
# ====> Epoch: 2 OD Test set loss: 2075.9458 Accuracy: 0.24
# ====> Epoch: 3 Average loss: 1936.8004 Accuracy: 0.64
# ====> Epoch: 3 ID Test set loss: 1936.2526 Accuracy: 0.72
# ====> Epoch: 3 OD Test set loss: 1980.0084 Accuracy: 0.20
# ====> Epoch: 3 Average loss: 1934.6621 Accuracy: 0.76
# ====> Epoch: 3 ID Test set loss: 1942.4468 Accuracy: 0.84
# ====> Epoch: 3 OD Test set loss: 1978.2018 Accuracy: 0.20
# ====> Epoch: 3 Average loss: 1937.2278 Accuracy: 0.88
# ====> Epoch: 3 ID Test set loss: 1974.8223 Accuracy: 0.88
# ====> Epoch: 3 OD Test set loss: 1964.7135 Accuracy: 0.24
# ====> Epoch: 3 Average loss: 1926.1844 Accuracy: 0.84
# ====> Epoch: 3 ID Test set loss: 1933.3363 Accuracy: 0.60
# ====> Epoch: 3 OD Test set loss: 1955.0775 Accuracy: 0.16
# ====> Epoch: 3 Average loss: 1941.9529 Accuracy: 0.60
# ====> Epoch: 3 ID Test set loss: 1932.3843 Accuracy: 0.84
# ====> Epoch: 3 OD Test set loss: 2046.8353 Accuracy: 0.16
# ====> Epoch: 3 Average loss: 1933.0298 Accuracy: 0.68
# ====> Epoch: 3 ID Test set loss: 1926.5829 Accuracy: 0.80
# ====> Epoch: 3 OD Test set loss: 1999.1250 Accuracy: 0.24
# ====> Epoch: 3 Average loss: 1924.4868 Accuracy: 0.76
# ====> Epoch: 3 ID Test set loss: 1929.8289 Accuracy: 0.80
# ====> Epoch: 3 OD Test set loss: 1977.7101 Accuracy: 0.12
# ====> Epoch: 3 Average loss: 1921.0139 Accuracy: 0.84
# ====> Epoch: 3 ID Test set loss: 1921.1719 Accuracy: 0.80
# ====> Epoch: 3 OD Test set loss: 1967.2767 Accuracy: 0.16
# ====> Epoch: 3 Average loss: 1923.6167 Accuracy: 0.92
# ====> Epoch: 3 ID Test set loss: 1922.4283 Accuracy: 0.84
# ====> Epoch: 3 OD Test set loss: 1993.0304 Accuracy: 0.28
# ====> Epoch: 3 Average loss: 1927.0994 Accuracy: 0.80
# ====> Epoch: 3 ID Test set loss: 1913.8186 Accuracy: 0.80
# ====> Epoch: 3 OD Test set loss: 1962.8801 Accuracy: 0.04
# ====> Epoch: 3 Average loss: 1914.3657 Accuracy: 0.80
# ====> Epoch: 3 ID Test set loss: 1909.3890 Accuracy: 0.88
# ====> Epoch: 3 OD Test set loss: 1969.4690 Accuracy: 0.20
# ====> Epoch: 4 Average loss: 1904.2183 Accuracy: 0.72
# ====> Epoch: 4 ID Test set loss: 1898.3596 Accuracy: 0.84
# ====> Epoch: 4 OD Test set loss: 1918.0460 Accuracy: 0.12
# ====> Epoch: 4 Average loss: 1897.7561 Accuracy: 0.76
# ====> Epoch: 4 ID Test set loss: 1893.2124 Accuracy: 0.80
# ====> Epoch: 4 OD Test set loss: 1915.8320 Accuracy: 0.36
# ====> Epoch: 4 Average loss: 1893.5654 Accuracy: 0.76
# ====> Epoch: 4 ID Test set loss: 1892.8466 Accuracy: 0.80
# ====> Epoch: 4 OD Test set loss: 1922.0437 Accuracy: 0.36
# ====> Epoch: 4 Average loss: 1890.7213 Accuracy: 0.84
# ====> Epoch: 4 ID Test set loss: 1885.3744 Accuracy: 0.76
# ====> Epoch: 4 OD Test set loss: 1914.3110 Accuracy: 0.28
# ====> Epoch: 4 Average loss: 1893.9509 Accuracy: 0.92
# ====> Epoch: 4 ID Test set loss: 1886.7273 Accuracy: 0.76
# ====> Epoch: 4 OD Test set loss: 1924.6666 Accuracy: 0.16
# ====> Epoch: 4 Average loss: 1899.7386 Accuracy: 0.80
# ====> Epoch: 4 ID Test set loss: 1889.2684 Accuracy: 0.72
# ====> Epoch: 4 OD Test set loss: 1922.3110 Accuracy: 0.16
# ====> Epoch: 4 Average loss: 1887.4154 Accuracy: 0.72
# ====> Epoch: 4 ID Test set loss: 1877.4017 Accuracy: 0.84
# ====> Epoch: 4 OD Test set loss: 1942.7067 Accuracy: 0.32
# ====> Epoch: 4 Average loss: 1880.7312 Accuracy: 0.84
# ====> Epoch: 4 ID Test set loss: 1883.4937 Accuracy: 0.84
# ====> Epoch: 4 OD Test set loss: 1919.9386 Accuracy: 0.24
# ====> Epoch: 4 Average loss: 1884.0848 Accuracy: 0.72
# ====> Epoch: 4 ID Test set loss: 1880.8231 Accuracy: 0.92
# ====> Epoch: 4 OD Test set loss: 1903.9644 Accuracy: 0.16
# ====> Epoch: 4 Average loss: 1888.3566 Accuracy: 0.60
# ====> Epoch: 4 ID Test set loss: 1869.3873 Accuracy: 0.88
# ====> Epoch: 4 OD Test set loss: 1921.7719 Accuracy: 0.24
# ====> Epoch: 4 Average loss: 1874.2921 Accuracy: 0.84
# ====> Epoch: 4 ID Test set loss: 1872.0123 Accuracy: 0.88
# ====> Epoch: 4 OD Test set loss: 1906.8767 Accuracy: 0.16
# ====> Epoch: 5 Average loss: 1867.9713 Accuracy: 0.72
# ====> Epoch: 5 ID Test set loss: 1868.5833 Accuracy: 0.88
# ====> Epoch: 5 OD Test set loss: 1887.9237 Accuracy: 0.16
# ====> Epoch: 5 Average loss: 1861.0870 Accuracy: 0.88
# ====> Epoch: 5 ID Test set loss: 1854.6794 Accuracy: 0.88
# ====> Epoch: 5 OD Test set loss: 1878.1351 Accuracy: 0.48
# ====> Epoch: 5 Average loss: 1855.6736 Accuracy: 0.88
# ====> Epoch: 5 ID Test set loss: 1855.6066 Accuracy: 0.72
# ====> Epoch: 5 OD Test set loss: 1891.4507 Accuracy: 0.12
# ====> Epoch: 5 Average loss: 1853.1079 Accuracy: 0.72
# ====> Epoch: 5 ID Test set loss: 1852.4271 Accuracy: 0.76
# ====> Epoch: 5 OD Test set loss: 1893.4729 Accuracy: 0.08
# ====> Epoch: 5 Average loss: 1857.1603 Accuracy: 0.92
# ====> Epoch: 5 ID Test set loss: 1847.2926 Accuracy: 0.80
# ====> Epoch: 5 OD Test set loss: 1892.8707 Accuracy: 0.20
# ====> Epoch: 5 Average loss: 1850.9009 Accuracy: 0.88
# ====> Epoch: 5 ID Test set loss: 1846.8767 Accuracy: 0.92
# ====> Epoch: 5 OD Test set loss: 1894.8634 Accuracy: 0.24
# ====> Epoch: 5 Average loss: 1852.1035 Accuracy: 0.84
# ====> Epoch: 5 ID Test set loss: 1844.5690 Accuracy: 0.92
# ====> Epoch: 5 OD Test set loss: 1868.4657 Accuracy: 0.12
# ====> Epoch: 5 Average loss: 1842.8081 Accuracy: 0.88
# ====> Epoch: 5 ID Test set loss: 1839.1187 Accuracy: 0.84
# ====> Epoch: 5 OD Test set loss: 1904.9384 Accuracy: 0.12
# ====> Epoch: 5 Average loss: 1843.5499 Accuracy: 0.92
# ====> Epoch: 5 ID Test set loss: 1839.0391 Accuracy: 0.88
# ====> Epoch: 5 OD Test set loss: 1875.1045 Accuracy: 0.28
# ====> Epoch: 5 Average loss: 1838.7469 Accuracy: 0.72
# ====> Epoch: 5 ID Test set loss: 1832.0508 Accuracy: 0.88
# ====> Epoch: 5 OD Test set loss: 1884.5923 Accuracy: 0.12
# ====> Epoch: 5 Average loss: 1835.0978 Accuracy: 0.84
# ====> Epoch: 5 ID Test set loss: 1826.6334 Accuracy: 0.80
# ====> Epoch: 5 OD Test set loss: 1860.2964 Accuracy: 0.20
# ====> Epoch: 6 Average loss: 1820.5046 Accuracy: 0.76
# ====> Epoch: 6 ID Test set loss: 1823.4138 Accuracy: 0.76
# ====> Epoch: 6 OD Test set loss: 1849.4762 Accuracy: 0.20
# ====> Epoch: 6 Average loss: 1812.1317 Accuracy: 0.84
# ====> Epoch: 6 ID Test set loss: 1811.5577 Accuracy: 0.88
# ====> Epoch: 6 OD Test set loss: 1832.6207 Accuracy: 0.36
# ====> Epoch: 6 Average loss: 1804.3286 Accuracy: 0.92
# ====> Epoch: 6 ID Test set loss: 1805.7684 Accuracy: 0.88
# ====> Epoch: 6 OD Test set loss: 1829.8641 Accuracy: 0.16
# ====> Epoch: 6 Average loss: 1797.4232 Accuracy: 0.92
# ====> Epoch: 6 ID Test set loss: 1796.4941 Accuracy: 0.96
# ====> Epoch: 6 OD Test set loss: 1840.3403 Accuracy: 0.08
# ====> Epoch: 6 Average loss: 1789.1931 Accuracy: 0.96
# ====> Epoch: 6 ID Test set loss: 1783.1315 Accuracy: 0.92
# ====> Epoch: 6 OD Test set loss: 1826.2751 Accuracy: 0.24
# ====> Epoch: 6 Average loss: 1788.2798 Accuracy: 0.88
# ====> Epoch: 6 ID Test set loss: 1779.2910 Accuracy: 0.96
# ====> Epoch: 6 OD Test set loss: 1829.5673 Accuracy: 0.16
# ====> Epoch: 6 Average loss: 1777.4885 Accuracy: 0.80
# ====> Epoch: 6 ID Test set loss: 1774.5204 Accuracy: 0.92
# ====> Epoch: 6 OD Test set loss: 1816.9603 Accuracy: 0.28
# ====> Epoch: 6 Average loss: 1771.8170 Accuracy: 0.88
# ====> Epoch: 6 ID Test set loss: 1767.1442 Accuracy: 0.84
# ====> Epoch: 6 OD Test set loss: 1799.7395 Accuracy: 0.24
# ====> Epoch: 6 Average loss: 1757.2196 Accuracy: 0.84
# ====> Epoch: 6 ID Test set loss: 1748.6859 Accuracy: 0.96
# ====> Epoch: 6 OD Test set loss: 1782.5197 Accuracy: 0.32
# ====> Epoch: 6 Average loss: 1748.8420 Accuracy: 0.84
# ====> Epoch: 6 ID Test set loss: 1748.3889 Accuracy: 0.88
# ====> Epoch: 6 OD Test set loss: 1782.2874 Accuracy: 0.36
# ====> Epoch: 6 Average loss: 1740.4219 Accuracy: 0.84
# ====> Epoch: 6 ID Test set loss: 1734.7758 Accuracy: 0.76
# ====> Epoch: 6 OD Test set loss: 1784.7932 Accuracy: 0.20
# ====> Epoch: 7 Average loss: 1716.6638 Accuracy: 0.68
# ====> Epoch: 7 ID Test set loss: 1702.2598 Accuracy: 0.92
# ====> Epoch: 7 OD Test set loss: 1742.5332 Accuracy: 0.36
# ====> Epoch: 7 Average loss: 1689.3064 Accuracy: 0.76
# ====> Epoch: 7 ID Test set loss: 1688.6257 Accuracy: 0.92
# ====> Epoch: 7 OD Test set loss: 1733.9609 Accuracy: 0.20
# ====> Epoch: 7 Average loss: 1676.9353 Accuracy: 0.92
# ====> Epoch: 7 ID Test set loss: 1667.6478 Accuracy: 0.88
# ====> Epoch: 7 OD Test set loss: 1715.1865 Accuracy: 0.12
# ====> Epoch: 7 Average loss: 1660.3646 Accuracy: 0.88
# ====> Epoch: 7 ID Test set loss: 1658.8906 Accuracy: 0.88
# ====> Epoch: 7 OD Test set loss: 1712.2528 Accuracy: 0.20
# ====> Epoch: 7 Average loss: 1641.2352 Accuracy: 0.84
# ====> Epoch: 7 ID Test set loss: 1632.1178 Accuracy: 0.76
# ====> Epoch: 7 OD Test set loss: 1698.7715 Accuracy: 0.16
# ====> Epoch: 7 Average loss: 1619.4983 Accuracy: 0.76
# ====> Epoch: 7 ID Test set loss: 1619.6758 Accuracy: 0.84
# ====> Epoch: 7 OD Test set loss: 1682.1191 Accuracy: 0.12
# ====> Epoch: 7 Average loss: 1597.9536 Accuracy: 0.96
# ====> Epoch: 7 ID Test set loss: 1597.6201 Accuracy: 0.84
# ====> Epoch: 7 OD Test set loss: 1638.1871 Accuracy: 0.28
# ====> Epoch: 7 Average loss: 1580.0903 Accuracy: 0.88
# ====> Epoch: 7 ID Test set loss: 1577.3545 Accuracy: 0.72
# ====> Epoch: 7 OD Test set loss: 1620.9983 Accuracy: 0.36
# ====> Epoch: 7 Average loss: 1551.4423 Accuracy: 0.92
# ====> Epoch: 7 ID Test set loss: 1547.9872 Accuracy: 1.00
# ====> Epoch: 7 OD Test set loss: 1603.0533 Accuracy: 0.28
# ====> Epoch: 7 Average loss: 1533.0217 Accuracy: 0.88
# ====> Epoch: 7 ID Test set loss: 1524.6624 Accuracy: 0.92
# ====> Epoch: 7 OD Test set loss: 1570.5494 Accuracy: 0.28
# ====> Epoch: 7 Average loss: 1496.1965 Accuracy: 0.88
# ====> Epoch: 7 ID Test set loss: 1499.2444 Accuracy: 0.96
# ====> Epoch: 7 OD Test set loss: 1563.3353 Accuracy: 0.20
# ====> Epoch: 8 Average loss: 1436.5603 Accuracy: 0.92
# ====> Epoch: 8 ID Test set loss: 1438.8583 Accuracy: 0.84
# ====> Epoch: 8 OD Test set loss: 1501.5599 Accuracy: 0.28
# ====> Epoch: 8 Average loss: 1401.2769 Accuracy: 0.80
# ====> Epoch: 8 ID Test set loss: 1405.9009 Accuracy: 1.00
# ====> Epoch: 8 OD Test set loss: 1462.9983 Accuracy: 0.20
# ====> Epoch: 8 Average loss: 1375.3794 Accuracy: 0.92
# ====> Epoch: 8 ID Test set loss: 1370.5680 Accuracy: 0.92
# ====> Epoch: 8 OD Test set loss: 1441.3845 Accuracy: 0.28
# ====> Epoch: 8 Average loss: 1338.0359 Accuracy: 0.84
# ====> Epoch: 8 ID Test set loss: 1334.5781 Accuracy: 0.92
# ====> Epoch: 8 OD Test set loss: 1384.4152 Accuracy: 0.44
# ====> Epoch: 8 Average loss: 1299.8527 Accuracy: 0.92
# ====> Epoch: 8 ID Test set loss: 1298.7736 Accuracy: 0.88
# ====> Epoch: 8 OD Test set loss: 1367.9561 Accuracy: 0.12
# ====> Epoch: 8 Average loss: 1258.8645 Accuracy: 0.84
# ====> Epoch: 8 ID Test set loss: 1265.5641 Accuracy: 0.80
# ====> Epoch: 8 OD Test set loss: 1332.7318 Accuracy: 0.32
# ====> Epoch: 8 Average loss: 1211.4902 Accuracy: 0.88
# ====> Epoch: 8 ID Test set loss: 1213.6925 Accuracy: 0.92
# ====> Epoch: 8 OD Test set loss: 1291.3844 Accuracy: 0.40
# ====> Epoch: 8 Average loss: 1219.1432 Accuracy: 0.80
# ====> Epoch: 8 ID Test set loss: 1174.4990 Accuracy: 0.96
# ====> Epoch: 8 OD Test set loss: 1258.5917 Accuracy: 0.24
# ====> Epoch: 8 Average loss: 1145.2709 Accuracy: 0.72
# ====> Epoch: 8 ID Test set loss: 1147.0920 Accuracy: 0.92
# ====> Epoch: 8 OD Test set loss: 1207.0438 Accuracy: 0.32
# ====> Epoch: 8 Average loss: 1091.6843 Accuracy: 0.84
# ====> Epoch: 8 ID Test set loss: 1081.6788 Accuracy: 0.96
# ====> Epoch: 8 OD Test set loss: 1165.4304 Accuracy: 0.20
# ====> Epoch: 8 Average loss: 1059.4265 Accuracy: 0.92
# ====> Epoch: 8 ID Test set loss: 1058.1256 Accuracy: 0.92
# ====> Epoch: 8 OD Test set loss: 1141.5804 Accuracy: 0.24
# ====> Epoch: 9 Average loss: 971.4043 Accuracy: 0.88
# ====> Epoch: 9 ID Test set loss: 949.0098 Accuracy: 0.84
# ====> Epoch: 9 OD Test set loss: 1042.8998 Accuracy: 0.36
# ====> Epoch: 9 Average loss: 915.5453 Accuracy: 0.96
# ====> Epoch: 9 ID Test set loss: 932.0484 Accuracy: 0.80
# ====> Epoch: 9 OD Test set loss: 983.4847 Accuracy: 0.24
# ====> Epoch: 9 Average loss: 875.4164 Accuracy: 0.92
# ====> Epoch: 9 ID Test set loss: 866.8859 Accuracy: 0.92
# ====> Epoch: 9 OD Test set loss: 982.5117 Accuracy: 0.24
# ====> Epoch: 9 Average loss: 870.3829 Accuracy: 0.92
# ====> Epoch: 9 ID Test set loss: 839.2509 Accuracy: 0.88
# ====> Epoch: 9 OD Test set loss: 952.9109 Accuracy: 0.24
# ====> Epoch: 9 Average loss: 824.6217 Accuracy: 0.92
# ====> Epoch: 9 ID Test set loss: 787.4754 Accuracy: 0.96
# ====> Epoch: 9 OD Test set loss: 934.5817 Accuracy: 0.16
# ====> Epoch: 9 Average loss: 799.3401 Accuracy: 0.88
# ====> Epoch: 9 ID Test set loss: 782.6700 Accuracy: 0.96
# ====> Epoch: 9 OD Test set loss: 889.1830 Accuracy: 0.24
# ====> Epoch: 9 Average loss: 767.2991 Accuracy: 0.88
# ====> Epoch: 9 ID Test set loss: 751.1734 Accuracy: 0.92
# ====> Epoch: 9 OD Test set loss: 845.0338 Accuracy: 0.24
# ====> Epoch: 9 Average loss: 693.0051 Accuracy: 0.96
# ====> Epoch: 9 ID Test set loss: 744.3176 Accuracy: 0.88
# ====> Epoch: 9 OD Test set loss: 785.4083 Accuracy: 0.24
# ====> Epoch: 9 Average loss: 712.5001 Accuracy: 0.80
# ====> Epoch: 9 ID Test set loss: 708.5060 Accuracy: 0.92
# ====> Epoch: 9 OD Test set loss: 784.6451 Accuracy: 0.24
# ====> Epoch: 9 Average loss: 682.9786 Accuracy: 0.96
# ====> Epoch: 9 ID Test set loss: 643.3122 Accuracy: 0.96
# ====> Epoch: 9 OD Test set loss: 765.8204 Accuracy: 0.24
# ====> Epoch: 9 Average loss: 672.9972 Accuracy: 0.92
# ====> Epoch: 9 ID Test set loss: 627.1697 Accuracy: 0.96
# ====> Epoch: 9 OD Test set loss: 737.7448 Accuracy: 0.20
# ====> Epoch: 10 Average loss: 589.1345 Accuracy: 0.96
# ====> Epoch: 10 ID Test set loss: 610.0722 Accuracy: 0.88
# ====> Epoch: 10 OD Test set loss: 739.4869 Accuracy: 0.24
# ====> Epoch: 10 Average loss: 604.2776 Accuracy: 0.84
# ====> Epoch: 10 ID Test set loss: 585.5580 Accuracy: 0.92
# ====> Epoch: 10 OD Test set loss: 667.2063 Accuracy: 0.24
# ====> Epoch: 10 Average loss: 560.4737 Accuracy: 0.96
# ====> Epoch: 10 ID Test set loss: 571.0576 Accuracy: 0.92
# ====> Epoch: 10 OD Test set loss: 701.0124 Accuracy: 0.28
# ====> Epoch: 10 Average loss: 580.9863 Accuracy: 0.96
# ====> Epoch: 10 ID Test set loss: 548.3048 Accuracy: 1.00
# ====> Epoch: 10 OD Test set loss: 640.3091 Accuracy: 0.12
# ====> Epoch: 10 Average loss: 554.3743 Accuracy: 0.96
# ====> Epoch: 10 ID Test set loss: 531.6633 Accuracy: 0.88
# ====> Epoch: 10 OD Test set loss: 613.0151 Accuracy: 0.40
# ====> Epoch: 10 Average loss: 525.6565 Accuracy: 0.92
# ====> Epoch: 10 ID Test set loss: 536.6816 Accuracy: 0.96
# ====> Epoch: 10 OD Test set loss: 700.3248 Accuracy: 0.24
# ====> Epoch: 10 Average loss: 542.9872 Accuracy: 0.92
# ====> Epoch: 10 ID Test set loss: 535.4360 Accuracy: 0.80
# ====> Epoch: 10 OD Test set loss: 617.2334 Accuracy: 0.44
# ====> Epoch: 10 Average loss: 559.3862 Accuracy: 0.96
# ====> Epoch: 10 ID Test set loss: 559.1398 Accuracy: 0.88
# ====> Epoch: 10 OD Test set loss: 629.4632 Accuracy: 0.32
# ====> Epoch: 10 Average loss: 490.4825 Accuracy: 0.96
# ====> Epoch: 10 ID Test set loss: 509.7425 Accuracy: 0.84
# ====> Epoch: 10 OD Test set loss: 615.7200 Accuracy: 0.44
# ====> Epoch: 10 Average loss: 546.0978 Accuracy: 0.96
# ====> Epoch: 10 ID Test set loss: 496.8960 Accuracy: 0.96
# ====> Epoch: 10 OD Test set loss: 645.1953 Accuracy: 0.12
# ====> Epoch: 10 Average loss: 472.8603 Accuracy: 1.00
# ====> Epoch: 10 ID Test set loss: 516.8162 Accuracy: 1.00
# ====> Epoch: 10 OD Test set loss: 586.5414 Accuracy: 0.28
# ====> Epoch: 11 Average loss: 461.0580 Accuracy: 0.96
# ====> Epoch: 11 ID Test set loss: 491.6511 Accuracy: 0.96
# ====> Epoch: 11 OD Test set loss: 557.2766 Accuracy: 0.24
# ====> Epoch: 11 Average loss: 451.9062 Accuracy: 0.96
# ====> Epoch: 11 ID Test set loss: 457.5734 Accuracy: 0.96
# ====> Epoch: 11 OD Test set loss: 524.9905 Accuracy: 0.32
# ====> Epoch: 11 Average loss: 469.4604 Accuracy: 0.92
# ====> Epoch: 11 ID Test set loss: 459.1309 Accuracy: 0.92
# ====> Epoch: 11 OD Test set loss: 511.4690 Accuracy: 0.28
# ====> Epoch: 11 Average loss: 468.7476 Accuracy: 0.92
# ====> Epoch: 11 ID Test set loss: 465.7037 Accuracy: 1.00
# ====> Epoch: 11 OD Test set loss: 585.1495 Accuracy: 0.20
# ====> Epoch: 11 Average loss: 428.0475 Accuracy: 0.96
# ====> Epoch: 11 ID Test set loss: 439.0661 Accuracy: 0.88
# ====> Epoch: 11 OD Test set loss: 541.3682 Accuracy: 0.28
# ====> Epoch: 11 Average loss: 458.0330 Accuracy: 1.00
# ====> Epoch: 11 ID Test set loss: 448.2393 Accuracy: 1.00
# ====> Epoch: 11 OD Test set loss: 598.6218 Accuracy: 0.24
# ====> Epoch: 11 Average loss: 427.2144 Accuracy: 0.96
# ====> Epoch: 11 ID Test set loss: 452.4131 Accuracy: 1.00
# ====> Epoch: 11 OD Test set loss: 546.8782 Accuracy: 0.20
# ====> Epoch: 11 Average loss: 465.9992 Accuracy: 1.00
# ====> Epoch: 11 ID Test set loss: 493.0844 Accuracy: 1.00
# ====> Epoch: 11 OD Test set loss: 536.6941 Accuracy: 0.20
# ====> Epoch: 11 Average loss: 478.0669 Accuracy: 1.00
# ====> Epoch: 11 ID Test set loss: 449.5981 Accuracy: 0.96
# ====> Epoch: 11 OD Test set loss: 558.3057 Accuracy: 0.32
# ====> Epoch: 11 Average loss: 473.2034 Accuracy: 0.96
# ====> Epoch: 11 ID Test set loss: 447.2409 Accuracy: 1.00
# ====> Epoch: 11 OD Test set loss: 606.2076 Accuracy: 0.20
# ====> Epoch: 11 Average loss: 452.8895 Accuracy: 0.92
# ====> Epoch: 11 ID Test set loss: 450.2781 Accuracy: 0.96
# ====> Epoch: 11 OD Test set loss: 581.4584 Accuracy: 0.20
# ====> Epoch: 12 Average loss: 412.4520 Accuracy: 0.96
# ====> Epoch: 12 ID Test set loss: 424.6428 Accuracy: 0.96
# ====> Epoch: 12 OD Test set loss: 553.4272 Accuracy: 0.24
# ====> Epoch: 12 Average loss: 395.3659 Accuracy: 1.00
# ====> Epoch: 12 ID Test set loss: 424.4905 Accuracy: 0.96
# ====> Epoch: 12 OD Test set loss: 515.2753 Accuracy: 0.56
# ====> Epoch: 12 Average loss: 434.2794 Accuracy: 1.00
# ====> Epoch: 12 ID Test set loss: 442.0264 Accuracy: 0.96
# ====> Epoch: 12 OD Test set loss: 559.8080 Accuracy: 0.24
# ====> Epoch: 12 Average loss: 404.4897 Accuracy: 1.00
# ====> Epoch: 12 ID Test set loss: 390.5697 Accuracy: 0.96
# ====> Epoch: 12 OD Test set loss: 538.7919 Accuracy: 0.20
# ====> Epoch: 12 Average loss: 425.2877 Accuracy: 0.88
# ====> Epoch: 12 ID Test set loss: 401.2203 Accuracy: 0.96
# ====> Epoch: 12 OD Test set loss: 578.7764 Accuracy: 0.16
# ====> Epoch: 12 Average loss: 457.8106 Accuracy: 0.96
# ====> Epoch: 12 ID Test set loss: 433.2039 Accuracy: 0.92
# ====> Epoch: 12 OD Test set loss: 536.8690 Accuracy: 0.20
# ====> Epoch: 12 Average loss: 429.2873 Accuracy: 0.96
# ====> Epoch: 12 ID Test set loss: 437.6588 Accuracy: 0.96
# ====> Epoch: 12 OD Test set loss: 606.9772 Accuracy: 0.32
# ====> Epoch: 12 Average loss: 427.1649 Accuracy: 0.88
# ====> Epoch: 12 ID Test set loss: 426.6527 Accuracy: 0.92
# ====> Epoch: 12 OD Test set loss: 511.0482 Accuracy: 0.24
# ====> Epoch: 12 Average loss: 420.8983 Accuracy: 0.96
# ====> Epoch: 12 ID Test set loss: 426.1850 Accuracy: 0.96
# ====> Epoch: 12 OD Test set loss: 607.2735 Accuracy: 0.40
# ====> Epoch: 12 Average loss: 400.9227 Accuracy: 0.96
# ====> Epoch: 12 ID Test set loss: 363.1035 Accuracy: 1.00
# ====> Epoch: 12 OD Test set loss: 553.2617 Accuracy: 0.16
# ====> Epoch: 12 Average loss: 428.4841 Accuracy: 0.84
# ====> Epoch: 12 ID Test set loss: 412.2279 Accuracy: 1.00
# ====> Epoch: 12 OD Test set loss: 480.8885 Accuracy: 0.32
# ====> Epoch: 13 Average loss: 388.2204 Accuracy: 1.00
# ====> Epoch: 13 ID Test set loss: 404.2329 Accuracy: 1.00
# ====> Epoch: 13 OD Test set loss: 506.5624 Accuracy: 0.16
# ====> Epoch: 13 Average loss: 386.2122 Accuracy: 1.00
# ====> Epoch: 13 ID Test set loss: 425.5751 Accuracy: 0.96
# ====> Epoch: 13 OD Test set loss: 486.0672 Accuracy: 0.28
# ====> Epoch: 13 Average loss: 376.7439 Accuracy: 0.92
# ====> Epoch: 13 ID Test set loss: 385.0776 Accuracy: 0.96
# ====> Epoch: 13 OD Test set loss: 500.6989 Accuracy: 0.36
# ====> Epoch: 13 Average loss: 408.3009 Accuracy: 0.96
# ====> Epoch: 13 ID Test set loss: 373.9173 Accuracy: 0.96
# ====> Epoch: 13 OD Test set loss: 514.9510 Accuracy: 0.20
# ====> Epoch: 13 Average loss: 392.6975 Accuracy: 0.96
# ====> Epoch: 13 ID Test set loss: 431.6257 Accuracy: 1.00
# ====> Epoch: 13 OD Test set loss: 535.0045 Accuracy: 0.20
# ====> Epoch: 13 Average loss: 357.9098 Accuracy: 0.96
# ====> Epoch: 13 ID Test set loss: 325.8444 Accuracy: 1.00
# ====> Epoch: 13 OD Test set loss: 487.9066 Accuracy: 0.32
# ====> Epoch: 13 Average loss: 369.3819 Accuracy: 0.92
# ====> Epoch: 13 ID Test set loss: 382.8394 Accuracy: 0.92
# ====> Epoch: 13 OD Test set loss: 499.0540 Accuracy: 0.36
# ====> Epoch: 13 Average loss: 350.8987 Accuracy: 1.00
# ====> Epoch: 13 ID Test set loss: 390.4693 Accuracy: 1.00
# ====> Epoch: 13 OD Test set loss: 457.3777 Accuracy: 0.28
# ====> Epoch: 13 Average loss: 471.4406 Accuracy: 1.00
# ====> Epoch: 13 ID Test set loss: 366.7788 Accuracy: 0.96
# ====> Epoch: 13 OD Test set loss: 459.9276 Accuracy: 0.36
# ====> Epoch: 13 Average loss: 379.3952 Accuracy: 1.00
# ====> Epoch: 13 ID Test set loss: 355.1029 Accuracy: 1.00
# ====> Epoch: 13 OD Test set loss: 526.5389 Accuracy: 0.40
# ====> Epoch: 13 Average loss: 355.1397 Accuracy: 0.96
# ====> Epoch: 13 ID Test set loss: 336.6766 Accuracy: 1.00
# ====> Epoch: 13 OD Test set loss: 527.9686 Accuracy: 0.32
# ====> Epoch: 14 Average loss: 432.9853 Accuracy: 1.00
# ====> Epoch: 14 ID Test set loss: 388.8663 Accuracy: 1.00
# ====> Epoch: 14 OD Test set loss: 437.8025 Accuracy: 0.24
# ====> Epoch: 14 Average loss: 373.1616 Accuracy: 1.00
# ====> Epoch: 14 ID Test set loss: 384.1124 Accuracy: 1.00
# ====> Epoch: 14 OD Test set loss: 571.5255 Accuracy: 0.08
# ====> Epoch: 14 Average loss: 364.9424 Accuracy: 0.96
# ====> Epoch: 14 ID Test set loss: 318.1054 Accuracy: 0.96
# ====> Epoch: 14 OD Test set loss: 423.8398 Accuracy: 0.28
# ====> Epoch: 14 Average loss: 370.2207 Accuracy: 1.00
# ====> Epoch: 14 ID Test set loss: 366.5042 Accuracy: 1.00
# ====> Epoch: 14 OD Test set loss: 535.4130 Accuracy: 0.24
# ====> Epoch: 14 Average loss: 368.2605 Accuracy: 0.92
# ====> Epoch: 14 ID Test set loss: 377.6285 Accuracy: 1.00
# ====> Epoch: 14 OD Test set loss: 537.2216 Accuracy: 0.24
# ====> Epoch: 14 Average loss: 377.8180 Accuracy: 1.00
# ====> Epoch: 14 ID Test set loss: 355.7655 Accuracy: 1.00
# ====> Epoch: 14 OD Test set loss: 582.3715 Accuracy: 0.24
# ====> Epoch: 14 Average loss: 356.4473 Accuracy: 1.00
# ====> Epoch: 14 ID Test set loss: 370.0322 Accuracy: 0.96
# ====> Epoch: 14 OD Test set loss: 444.8314 Accuracy: 0.24
# ====> Epoch: 14 Average loss: 338.3553 Accuracy: 1.00
# ====> Epoch: 14 ID Test set loss: 364.9853 Accuracy: 0.96
# ====> Epoch: 14 OD Test set loss: 553.3688 Accuracy: 0.24
# ====> Epoch: 14 Average loss: 326.9402 Accuracy: 1.00
# ====> Epoch: 14 ID Test set loss: 324.5467 Accuracy: 1.00
# ====> Epoch: 14 OD Test set loss: 522.5582 Accuracy: 0.20
# ====> Epoch: 14 Average loss: 405.0366 Accuracy: 1.00
# ====> Epoch: 14 ID Test set loss: 362.2276 Accuracy: 1.00
# ====> Epoch: 14 OD Test set loss: 475.5177 Accuracy: 0.40
# ====> Epoch: 14 Average loss: 337.9180 Accuracy: 1.00
# ====> Epoch: 14 ID Test set loss: 384.9883 Accuracy: 1.00
# ====> Epoch: 14 OD Test set loss: 531.4299 Accuracy: 0.20
# ====> Epoch: 15 Average loss: 353.1989 Accuracy: 0.96
# ====> Epoch: 15 ID Test set loss: 359.4383 Accuracy: 0.92
# ====> Epoch: 15 OD Test set loss: 473.0540 Accuracy: 0.24
# ====> Epoch: 15 Average loss: 342.9896 Accuracy: 1.00
# ====> Epoch: 15 ID Test set loss: 358.3434 Accuracy: 0.96
# ====> Epoch: 15 OD Test set loss: 473.6557 Accuracy: 0.20
# ====> Epoch: 15 Average loss: 328.7283 Accuracy: 1.00
# ====> Epoch: 15 ID Test set loss: 343.0780 Accuracy: 1.00
# ====> Epoch: 15 OD Test set loss: 494.7537 Accuracy: 0.24
# ====> Epoch: 15 Average loss: 327.9473 Accuracy: 0.96
# ====> Epoch: 15 ID Test set loss: 354.6919 Accuracy: 1.00
# ====> Epoch: 15 OD Test set loss: 500.1740 Accuracy: 0.20
# ====> Epoch: 15 Average loss: 355.3932 Accuracy: 1.00
# ====> Epoch: 15 ID Test set loss: 378.7570 Accuracy: 0.96
# ====> Epoch: 15 OD Test set loss: 502.9752 Accuracy: 0.20
# ====> Epoch: 15 Average loss: 339.9020 Accuracy: 0.96
# ====> Epoch: 15 ID Test set loss: 365.5814 Accuracy: 0.92
# ====> Epoch: 15 OD Test set loss: 568.8535 Accuracy: 0.28
# ====> Epoch: 15 Average loss: 409.8824 Accuracy: 0.96
# ====> Epoch: 15 ID Test set loss: 346.0792 Accuracy: 1.00
# ====> Epoch: 15 OD Test set loss: 435.4367 Accuracy: 0.32
# ====> Epoch: 15 Average loss: 385.8885 Accuracy: 0.92
# ====> Epoch: 15 ID Test set loss: 351.0554 Accuracy: 1.00
# ====> Epoch: 15 OD Test set loss: 442.9349 Accuracy: 0.36
# ====> Epoch: 15 Average loss: 378.8721 Accuracy: 0.96
# ====> Epoch: 15 ID Test set loss: 335.3333 Accuracy: 1.00
# ====> Epoch: 15 OD Test set loss: 464.8099 Accuracy: 0.36
# ====> Epoch: 15 Average loss: 380.1032 Accuracy: 1.00
# ====> Epoch: 15 ID Test set loss: 328.6989 Accuracy: 0.92
# ====> Epoch: 15 OD Test set loss: 455.1846 Accuracy: 0.28
# ====> Epoch: 15 Average loss: 375.0283 Accuracy: 1.00
# ====> Epoch: 15 ID Test set loss: 339.6188 Accuracy: 1.00
# ====> Epoch: 15 OD Test set loss: 509.1617 Accuracy: 0.20
# ====> Epoch: 16 Average loss: 330.8502 Accuracy: 1.00
# ====> Epoch: 16 ID Test set loss: 355.2334 Accuracy: 1.00
# ====> Epoch: 16 OD Test set loss: 436.2068 Accuracy: 0.32
# ====> Epoch: 16 Average loss: 359.7164 Accuracy: 1.00
# ====> Epoch: 16 ID Test set loss: 334.8978 Accuracy: 0.96
# ====> Epoch: 16 OD Test set loss: 504.5065 Accuracy: 0.16
# ====> Epoch: 16 Average loss: 343.3047 Accuracy: 1.00
# ====> Epoch: 16 ID Test set loss: 331.6360 Accuracy: 0.96
# ====> Epoch: 16 OD Test set loss: 499.8534 Accuracy: 0.16
# ====> Epoch: 16 Average loss: 330.8927 Accuracy: 0.96
# ====> Epoch: 16 ID Test set loss: 380.4140 Accuracy: 0.96
# ====> Epoch: 16 OD Test set loss: 479.4987 Accuracy: 0.24
# ====> Epoch: 16 Average loss: 359.1371 Accuracy: 1.00
# ====> Epoch: 16 ID Test set loss: 329.0985 Accuracy: 0.96
# ====> Epoch: 16 OD Test set loss: 498.6189 Accuracy: 0.24
# ====> Epoch: 16 Average loss: 335.9265 Accuracy: 1.00
# ====> Epoch: 16 ID Test set loss: 300.5145 Accuracy: 1.00
# ====> Epoch: 16 OD Test set loss: 410.5044 Accuracy: 0.24
# ====> Epoch: 16 Average loss: 340.6763 Accuracy: 1.00
# ====> Epoch: 16 ID Test set loss: 378.2835 Accuracy: 0.92
# ====> Epoch: 16 OD Test set loss: 496.5766 Accuracy: 0.24
# ====> Epoch: 16 Average loss: 341.0620 Accuracy: 0.96
# ====> Epoch: 16 ID Test set loss: 345.7750 Accuracy: 0.92
# ====> Epoch: 16 OD Test set loss: 529.7640 Accuracy: 0.24
# ====> Epoch: 16 Average loss: 339.1346 Accuracy: 1.00
# ====> Epoch: 16 ID Test set loss: 322.7300 Accuracy: 1.00
# ====> Epoch: 16 OD Test set loss: 531.3073 Accuracy: 0.16
# ====> Epoch: 16 Average loss: 342.6903 Accuracy: 1.00
# ====> Epoch: 16 ID Test set loss: 351.0394 Accuracy: 1.00
# ====> Epoch: 16 OD Test set loss: 510.1393 Accuracy: 0.16
# ====> Epoch: 16 Average loss: 352.8704 Accuracy: 1.00
# ====> Epoch: 16 ID Test set loss: 368.3509 Accuracy: 0.96
# ====> Epoch: 16 OD Test set loss: 439.8099 Accuracy: 0.16
# ====> Epoch: 17 Average loss: 375.6992 Accuracy: 1.00
# ====> Epoch: 17 ID Test set loss: 343.7722 Accuracy: 0.96
# ====> Epoch: 17 OD Test set loss: 566.6572 Accuracy: 0.20
# ====> Epoch: 17 Average loss: 328.9675 Accuracy: 1.00
# ====> Epoch: 17 ID Test set loss: 336.6615 Accuracy: 1.00
# ====> Epoch: 17 OD Test set loss: 466.1957 Accuracy: 0.36
# ====> Epoch: 17 Average loss: 333.2509 Accuracy: 1.00
# ====> Epoch: 17 ID Test set loss: 325.5056 Accuracy: 1.00
# ====> Epoch: 17 OD Test set loss: 486.2501 Accuracy: 0.24
# ====> Epoch: 17 Average loss: 360.7635 Accuracy: 0.96
# ====> Epoch: 17 ID Test set loss: 336.9922 Accuracy: 0.96
# ====> Epoch: 17 OD Test set loss: 445.6562 Accuracy: 0.24
# ====> Epoch: 17 Average loss: 374.0728 Accuracy: 0.96
# ====> Epoch: 17 ID Test set loss: 330.7837 Accuracy: 0.92
# ====> Epoch: 17 OD Test set loss: 523.5554 Accuracy: 0.12
# ====> Epoch: 17 Average loss: 384.8974 Accuracy: 1.00
# ====> Epoch: 17 ID Test set loss: 379.2317 Accuracy: 0.96
# ====> Epoch: 17 OD Test set loss: 505.2512 Accuracy: 0.20
# ====> Epoch: 17 Average loss: 362.5203 Accuracy: 1.00
# ====> Epoch: 17 ID Test set loss: 319.2912 Accuracy: 1.00
# ====> Epoch: 17 OD Test set loss: 480.9356 Accuracy: 0.12
# ====> Epoch: 17 Average loss: 413.1737 Accuracy: 0.96
# ====> Epoch: 17 ID Test set loss: 338.4320 Accuracy: 1.00
# ====> Epoch: 17 OD Test set loss: 518.7701 Accuracy: 0.28
# ====> Epoch: 17 Average loss: 330.0540 Accuracy: 0.96
# ====> Epoch: 17 ID Test set loss: 339.2346 Accuracy: 1.00
# ====> Epoch: 17 OD Test set loss: 507.5639 Accuracy: 0.24
# ====> Epoch: 17 Average loss: 391.8849 Accuracy: 0.96
# ====> Epoch: 17 ID Test set loss: 362.9377 Accuracy: 0.96
# ====> Epoch: 17 OD Test set loss: 529.4006 Accuracy: 0.28
# ====> Epoch: 17 Average loss: 384.5664 Accuracy: 0.92
# ====> Epoch: 17 ID Test set loss: 330.4603 Accuracy: 0.96
# ====> Epoch: 17 OD Test set loss: 486.2199 Accuracy: 0.28
# ====> Epoch: 18 Average loss: 391.3860 Accuracy: 1.00
# ====> Epoch: 18 ID Test set loss: 345.2626 Accuracy: 1.00
# ====> Epoch: 18 OD Test set loss: 537.5801 Accuracy: 0.32
# ====> Epoch: 18 Average loss: 384.8402 Accuracy: 0.96
# ====> Epoch: 18 ID Test set loss: 409.6061 Accuracy: 1.00
# ====> Epoch: 18 OD Test set loss: 535.5936 Accuracy: 0.12
# ====> Epoch: 18 Average loss: 352.3296 Accuracy: 1.00
# ====> Epoch: 18 ID Test set loss: 395.2650 Accuracy: 0.84
# ====> Epoch: 18 OD Test set loss: 465.2086 Accuracy: 0.32
# ====> Epoch: 18 Average loss: 361.9757 Accuracy: 1.00
# ====> Epoch: 18 ID Test set loss: 380.0087 Accuracy: 0.96
# ====> Epoch: 18 OD Test set loss: 466.7301 Accuracy: 0.40
# ====> Epoch: 18 Average loss: 328.4988 Accuracy: 1.00
# ====> Epoch: 18 ID Test set loss: 346.3590 Accuracy: 0.96
# ====> Epoch: 18 OD Test set loss: 469.7292 Accuracy: 0.32
# ====> Epoch: 18 Average loss: 322.3612 Accuracy: 0.96
# ====> Epoch: 18 ID Test set loss: 352.0204 Accuracy: 1.00
# ====> Epoch: 18 OD Test set loss: 456.8357 Accuracy: 0.12
# ====> Epoch: 18 Average loss: 346.8679 Accuracy: 1.00
# ====> Epoch: 18 ID Test set loss: 395.1906 Accuracy: 1.00
# ====> Epoch: 18 OD Test set loss: 442.8371 Accuracy: 0.12
# ====> Epoch: 18 Average loss: 357.0238 Accuracy: 1.00
# ====> Epoch: 18 ID Test set loss: 375.9459 Accuracy: 1.00
# ====> Epoch: 18 OD Test set loss: 445.1455 Accuracy: 0.20
# ====> Epoch: 18 Average loss: 340.2883 Accuracy: 1.00
# ====> Epoch: 18 ID Test set loss: 343.0369 Accuracy: 0.92
# ====> Epoch: 18 OD Test set loss: 537.1007 Accuracy: 0.28
# ====> Epoch: 18 Average loss: 363.6354 Accuracy: 0.96
# ====> Epoch: 18 ID Test set loss: 351.1153 Accuracy: 1.00
# ====> Epoch: 18 OD Test set loss: 525.4701 Accuracy: 0.08
# ====> Epoch: 18 Average loss: 355.6510 Accuracy: 0.96
# ====> Epoch: 18 ID Test set loss: 382.8884 Accuracy: 1.00
# ====> Epoch: 18 OD Test set loss: 498.1651 Accuracy: 0.16
# ====> Epoch: 19 Average loss: 368.4607 Accuracy: 1.00
# ====> Epoch: 19 ID Test set loss: 376.0542 Accuracy: 1.00
# ====> Epoch: 19 OD Test set loss: 460.6408 Accuracy: 0.32
# ====> Epoch: 19 Average loss: 357.1111 Accuracy: 1.00
# ====> Epoch: 19 ID Test set loss: 378.9080 Accuracy: 0.96
# ====> Epoch: 19 OD Test set loss: 433.2359 Accuracy: 0.32
# ====> Epoch: 19 Average loss: 355.4836 Accuracy: 0.84
# ====> Epoch: 19 ID Test set loss: 350.8851 Accuracy: 0.92
# ====> Epoch: 19 OD Test set loss: 504.0182 Accuracy: 0.28
# ====> Epoch: 19 Average loss: 318.4841 Accuracy: 1.00
# ====> Epoch: 19 ID Test set loss: 321.9928 Accuracy: 0.96
# ====> Epoch: 19 OD Test set loss: 507.6799 Accuracy: 0.20
# ====> Epoch: 19 Average loss: 394.1943 Accuracy: 1.00
# ====> Epoch: 19 ID Test set loss: 381.4226 Accuracy: 0.96
# ====> Epoch: 19 OD Test set loss: 515.5225 Accuracy: 0.40
# ====> Epoch: 19 Average loss: 355.2702 Accuracy: 1.00
# ====> Epoch: 19 ID Test set loss: 398.5261 Accuracy: 1.00
# ====> Epoch: 19 OD Test set loss: 484.8150 Accuracy: 0.36
# ====> Epoch: 19 Average loss: 369.5640 Accuracy: 0.96
# ====> Epoch: 19 ID Test set loss: 384.4066 Accuracy: 0.92
# ====> Epoch: 19 OD Test set loss: 486.7301 Accuracy: 0.48
# ====> Epoch: 19 Average loss: 379.8770 Accuracy: 1.00
# ====> Epoch: 19 ID Test set loss: 374.0679 Accuracy: 1.00
# ====> Epoch: 19 OD Test set loss: 503.8804 Accuracy: 0.16
# ====> Epoch: 19 Average loss: 341.5020 Accuracy: 1.00
# ====> Epoch: 19 ID Test set loss: 346.5516 Accuracy: 1.00
# ====> Epoch: 19 OD Test set loss: 563.5559 Accuracy: 0.24
# ====> Epoch: 19 Average loss: 371.1336 Accuracy: 0.96
# ====> Epoch: 19 ID Test set loss: 411.2902 Accuracy: 1.00
# ====> Epoch: 19 OD Test set loss: 518.2812 Accuracy: 0.20
# ====> Epoch: 19 Average loss: 361.6701 Accuracy: 0.96
# ====> Epoch: 19 ID Test set loss: 362.1963 Accuracy: 1.00
# ====> Epoch: 19 OD Test set loss: 484.1073 Accuracy: 0.20
# ====> Epoch: 20 Average loss: 432.7281 Accuracy: 0.96
# ====> Epoch: 20 ID Test set loss: 385.4543 Accuracy: 1.00
# ====> Epoch: 20 OD Test set loss: 559.0739 Accuracy: 0.24
# ====> Epoch: 20 Average loss: 366.2322 Accuracy: 0.92
# ====> Epoch: 20 ID Test set loss: 374.8062 Accuracy: 1.00
# ====> Epoch: 20 OD Test set loss: 469.2589 Accuracy: 0.40
# ====> Epoch: 20 Average loss: 351.7923 Accuracy: 1.00
# ====> Epoch: 20 ID Test set loss: 342.9547 Accuracy: 1.00
# ====> Epoch: 20 OD Test set loss: 514.5812 Accuracy: 0.24
# ====> Epoch: 20 Average loss: 363.6653 Accuracy: 0.96
# ====> Epoch: 20 ID Test set loss: 371.1046 Accuracy: 1.00
# ====> Epoch: 20 OD Test set loss: 464.3880 Accuracy: 0.36
# ====> Epoch: 20 Average loss: 341.6044 Accuracy: 1.00
# ====> Epoch: 20 ID Test set loss: 380.9611 Accuracy: 0.88
# ====> Epoch: 20 OD Test set loss: 411.3254 Accuracy: 0.44
# ====> Epoch: 20 Average loss: 377.0825 Accuracy: 1.00
# ====> Epoch: 20 ID Test set loss: 352.6884 Accuracy: 1.00
# ====> Epoch: 20 OD Test set loss: 463.6165 Accuracy: 0.20
# ====> Epoch: 20 Average loss: 346.2003 Accuracy: 0.92
# ====> Epoch: 20 ID Test set loss: 327.4552 Accuracy: 1.00
# ====> Epoch: 20 OD Test set loss: 526.1579 Accuracy: 0.28
# ====> Epoch: 20 Average loss: 342.6874 Accuracy: 0.96
# ====> Epoch: 20 ID Test set loss: 357.1026 Accuracy: 0.96
# ====> Epoch: 20 OD Test set loss: 490.7752 Accuracy: 0.40
# ====> Epoch: 20 Average loss: 371.1329 Accuracy: 1.00
# ====> Epoch: 20 ID Test set loss: 341.6373 Accuracy: 1.00
# ====> Epoch: 20 OD Test set loss: 550.9749 Accuracy: 0.24
# ====> Epoch: 20 Average loss: 371.3903 Accuracy: 1.00
# ====> Epoch: 20 ID Test set loss: 364.5550 Accuracy: 1.00
# ====> Epoch: 20 OD Test set loss: 556.3659 Accuracy: 0.24
# ====> Epoch: 20 Average loss: 367.5280 Accuracy: 1.00
# ====> Epoch: 20 ID Test set loss: 364.9303 Accuracy: 0.88
# ====> Epoch: 20 OD Test set loss: 533.1902 Accuracy: 0.16
# ====> Epoch: 21 Average loss: 349.4294 Accuracy: 1.00
# ====> Epoch: 21 ID Test set loss: 378.8083 Accuracy: 0.96
# ====> Epoch: 21 OD Test set loss: 469.4832 Accuracy: 0.12
# ====> Epoch: 21 Average loss: 346.2231 Accuracy: 0.96
# ====> Epoch: 21 ID Test set loss: 326.0559 Accuracy: 1.00
# ====> Epoch: 21 OD Test set loss: 514.3440 Accuracy: 0.16
# ====> Epoch: 21 Average loss: 326.3402 Accuracy: 1.00
# ====> Epoch: 21 ID Test set loss: 360.4046 Accuracy: 1.00
# ====> Epoch: 21 OD Test set loss: 422.2542 Accuracy: 0.40
# ====> Epoch: 21 Average loss: 360.7787 Accuracy: 1.00
# ====> Epoch: 21 ID Test set loss: 366.4799 Accuracy: 0.96
# ====> Epoch: 21 OD Test set loss: 521.1269 Accuracy: 0.20
# ====> Epoch: 21 Average loss: 340.8424 Accuracy: 1.00
# ====> Epoch: 21 ID Test set loss: 342.6169 Accuracy: 1.00
# ====> Epoch: 21 OD Test set loss: 523.4488 Accuracy: 0.24
# ====> Epoch: 21 Average loss: 386.1368 Accuracy: 1.00
# ====> Epoch: 21 ID Test set loss: 337.0897 Accuracy: 1.00
# ====> Epoch: 21 OD Test set loss: 502.5728 Accuracy: 0.20
# ====> Epoch: 21 Average loss: 394.4517 Accuracy: 0.96
# ====> Epoch: 21 ID Test set loss: 376.0446 Accuracy: 1.00
# ====> Epoch: 21 OD Test set loss: 578.8265 Accuracy: 0.24
# ====> Epoch: 21 Average loss: 386.8231 Accuracy: 0.96
# ====> Epoch: 21 ID Test set loss: 372.5052 Accuracy: 0.92
# ====> Epoch: 21 OD Test set loss: 539.8373 Accuracy: 0.12
# ====> Epoch: 21 Average loss: 363.6386 Accuracy: 0.96
# ====> Epoch: 21 ID Test set loss: 382.5580 Accuracy: 1.00
# ====> Epoch: 21 OD Test set loss: 505.3561 Accuracy: 0.20
# ====> Epoch: 21 Average loss: 338.0396 Accuracy: 0.96
# ====> Epoch: 21 ID Test set loss: 329.9954 Accuracy: 1.00
# ====> Epoch: 21 OD Test set loss: 487.0154 Accuracy: 0.32
# ====> Epoch: 21 Average loss: 334.8133 Accuracy: 1.00
# ====> Epoch: 21 ID Test set loss: 390.6012 Accuracy: 0.96
# ====> Epoch: 21 OD Test set loss: 543.1910 Accuracy: 0.32
# ====> Epoch: 22 Average loss: 331.4530 Accuracy: 1.00
# ====> Epoch: 22 ID Test set loss: 366.6097 Accuracy: 1.00
# ====> Epoch: 22 OD Test set loss: 566.0477 Accuracy: 0.20
# ====> Epoch: 22 Average loss: 373.8030 Accuracy: 1.00
# ====> Epoch: 22 ID Test set loss: 361.5346 Accuracy: 0.96
# ====> Epoch: 22 OD Test set loss: 514.2056 Accuracy: 0.36
# ====> Epoch: 22 Average loss: 377.2010 Accuracy: 1.00
# ====> Epoch: 22 ID Test set loss: 403.8383 Accuracy: 1.00
# ====> Epoch: 22 OD Test set loss: 523.9614 Accuracy: 0.40
# ====> Epoch: 22 Average loss: 327.7183 Accuracy: 1.00
# ====> Epoch: 22 ID Test set loss: 368.7996 Accuracy: 1.00
# ====> Epoch: 22 OD Test set loss: 442.6325 Accuracy: 0.52
# ====> Epoch: 22 Average loss: 380.2538 Accuracy: 1.00
# ====> Epoch: 22 ID Test set loss: 388.2502 Accuracy: 1.00
# ====> Epoch: 22 OD Test set loss: 614.8458 Accuracy: 0.16
# ====> Epoch: 22 Average loss: 361.0650 Accuracy: 0.84
# ====> Epoch: 22 ID Test set loss: 421.9872 Accuracy: 0.84
# ====> Epoch: 22 OD Test set loss: 530.4794 Accuracy: 0.20
# ====> Epoch: 22 Average loss: 422.9404 Accuracy: 0.96
# ====> Epoch: 22 ID Test set loss: 398.7539 Accuracy: 0.88
# ====> Epoch: 22 OD Test set loss: 589.1809 Accuracy: 0.24
# ====> Epoch: 22 Average loss: 382.6960 Accuracy: 1.00
# ====> Epoch: 22 ID Test set loss: 378.3926 Accuracy: 0.96
# ====> Epoch: 22 OD Test set loss: 522.7001 Accuracy: 0.44
# ====> Epoch: 22 Average loss: 337.8674 Accuracy: 0.96
# ====> Epoch: 22 ID Test set loss: 350.2542 Accuracy: 0.92
# ====> Epoch: 22 OD Test set loss: 649.1520 Accuracy: 0.16
# ====> Epoch: 22 Average loss: 423.7163 Accuracy: 0.96
# ====> Epoch: 22 ID Test set loss: 440.9900 Accuracy: 0.96
# ====> Epoch: 22 OD Test set loss: 606.8598 Accuracy: 0.28
# ====> Epoch: 22 Average loss: 414.3221 Accuracy: 0.92
# ====> Epoch: 22 ID Test set loss: 375.4840 Accuracy: 1.00
# ====> Epoch: 22 OD Test set loss: 521.1554 Accuracy: 0.20
# ====> Epoch: 23 Average loss: 371.6275 Accuracy: 1.00
# ====> Epoch: 23 ID Test set loss: 371.9785 Accuracy: 1.00
# ====> Epoch: 23 OD Test set loss: 595.3603 Accuracy: 0.20
# ====> Epoch: 23 Average loss: 403.8684 Accuracy: 0.92
# ====> Epoch: 23 ID Test set loss: 423.5901 Accuracy: 1.00
# ====> Epoch: 23 OD Test set loss: 588.6229 Accuracy: 0.20
# ====> Epoch: 23 Average loss: 392.1517 Accuracy: 0.96
# ====> Epoch: 23 ID Test set loss: 413.4051 Accuracy: 1.00
# ====> Epoch: 23 OD Test set loss: 507.8187 Accuracy: 0.24
# ====> Epoch: 23 Average loss: 379.5981 Accuracy: 1.00
# ====> Epoch: 23 ID Test set loss: 362.7003 Accuracy: 1.00
# ====> Epoch: 23 OD Test set loss: 512.3412 Accuracy: 0.24
# ====> Epoch: 23 Average loss: 391.3557 Accuracy: 1.00
# ====> Epoch: 23 ID Test set loss: 370.2485 Accuracy: 1.00
# ====> Epoch: 23 OD Test set loss: 493.8147 Accuracy: 0.36
# ====> Epoch: 23 Average loss: 370.3167 Accuracy: 1.00
# ====> Epoch: 23 ID Test set loss: 391.0333 Accuracy: 1.00
# ====> Epoch: 23 OD Test set loss: 599.6915 Accuracy: 0.20
# ====> Epoch: 23 Average loss: 343.4485 Accuracy: 0.96
# ====> Epoch: 23 ID Test set loss: 364.3608 Accuracy: 0.96
# ====> Epoch: 23 OD Test set loss: 470.8769 Accuracy: 0.40
# ====> Epoch: 23 Average loss: 339.0945 Accuracy: 1.00
# ====> Epoch: 23 ID Test set loss: 342.2674 Accuracy: 1.00
# ====> Epoch: 23 OD Test set loss: 517.4792 Accuracy: 0.40
# ====> Epoch: 23 Average loss: 403.7422 Accuracy: 0.96
# ====> Epoch: 23 ID Test set loss: 398.2802 Accuracy: 0.96
# ====> Epoch: 23 OD Test set loss: 573.0538 Accuracy: 0.28
# ====> Epoch: 23 Average loss: 388.7172 Accuracy: 1.00
# ====> Epoch: 23 ID Test set loss: 333.1183 Accuracy: 0.96
# ====> Epoch: 23 OD Test set loss: 480.3523 Accuracy: 0.36
# ====> Epoch: 23 Average loss: 437.5889 Accuracy: 0.84
# ====> Epoch: 23 ID Test set loss: 412.8358 Accuracy: 0.68
# ====> Epoch: 23 OD Test set loss: 570.5353 Accuracy: 0.32
# ====> Epoch: 24 Average loss: 375.6830 Accuracy: 1.00
# ====> Epoch: 24 ID Test set loss: 374.7795 Accuracy: 1.00
# ====> Epoch: 24 OD Test set loss: 518.5664 Accuracy: 0.36
# ====> Epoch: 24 Average loss: 370.4793 Accuracy: 0.96
# ====> Epoch: 24 ID Test set loss: 374.5349 Accuracy: 1.00
# ====> Epoch: 24 OD Test set loss: 528.5922 Accuracy: 0.32
# ====> Epoch: 24 Average loss: 366.6546 Accuracy: 1.00
# ====> Epoch: 24 ID Test set loss: 371.2819 Accuracy: 1.00
# ====> Epoch: 24 OD Test set loss: 547.9340 Accuracy: 0.12
# ====> Epoch: 24 Average loss: 333.2590 Accuracy: 1.00
# ====> Epoch: 24 ID Test set loss: 359.9428 Accuracy: 1.00
# ====> Epoch: 24 OD Test set loss: 574.5815 Accuracy: 0.00
# ====> Epoch: 24 Average loss: 370.1889 Accuracy: 0.96
# ====> Epoch: 24 ID Test set loss: 374.2821 Accuracy: 1.00
# ====> Epoch: 24 OD Test set loss: 520.4402 Accuracy: 0.32
# ====> Epoch: 24 Average loss: 371.6012 Accuracy: 1.00
# ====> Epoch: 24 ID Test set loss: 375.2061 Accuracy: 0.96
# ====> Epoch: 24 OD Test set loss: 509.6562 Accuracy: 0.44
# ====> Epoch: 24 Average loss: 396.8818 Accuracy: 0.96
# ====> Epoch: 24 ID Test set loss: 360.0558 Accuracy: 1.00
# ====> Epoch: 24 OD Test set loss: 551.5713 Accuracy: 0.16
# ====> Epoch: 24 Average loss: 368.8899 Accuracy: 1.00
# ====> Epoch: 24 ID Test set loss: 411.6949 Accuracy: 0.96
# ====> Epoch: 24 OD Test set loss: 531.6813 Accuracy: 0.32
# ====> Epoch: 24 Average loss: 370.1664 Accuracy: 1.00
# ====> Epoch: 24 ID Test set loss: 402.4442 Accuracy: 0.96
# ====> Epoch: 24 OD Test set loss: 565.9599 Accuracy: 0.28
# ====> Epoch: 24 Average loss: 378.6018 Accuracy: 1.00
# ====> Epoch: 24 ID Test set loss: 340.1164 Accuracy: 1.00
# ====> Epoch: 24 OD Test set loss: 483.5787 Accuracy: 0.32
# ====> Epoch: 24 Average loss: 339.7105 Accuracy: 1.00
# ====> Epoch: 24 ID Test set loss: 366.2348 Accuracy: 1.00
# ====> Epoch: 24 OD Test set loss: 500.0389 Accuracy: 0.24
# ====> Epoch: 25 Average loss: 376.3074 Accuracy: 1.00
# ====> Epoch: 25 ID Test set loss: 359.2075 Accuracy: 1.00
# ====> Epoch: 25 OD Test set loss: 499.6070 Accuracy: 0.44
# ====> Epoch: 25 Average loss: 345.8046 Accuracy: 0.96
# ====> Epoch: 25 ID Test set loss: 361.1798 Accuracy: 1.00
# ====> Epoch: 25 OD Test set loss: 542.5937 Accuracy: 0.24
# ====> Epoch: 25 Average loss: 374.2054 Accuracy: 1.00
# ====> Epoch: 25 ID Test set loss: 383.6832 Accuracy: 1.00
# ====> Epoch: 25 OD Test set loss: 538.5745 Accuracy: 0.20
# ====> Epoch: 25 Average loss: 337.7121 Accuracy: 1.00
# ====> Epoch: 25 ID Test set loss: 340.7620 Accuracy: 1.00
# ====> Epoch: 25 OD Test set loss: 499.8358 Accuracy: 0.28
# ====> Epoch: 25 Average loss: 349.3548 Accuracy: 0.96
# ====> Epoch: 25 ID Test set loss: 381.5907 Accuracy: 1.00
# ====> Epoch: 25 OD Test set loss: 485.0829 Accuracy: 0.36
# ====> Epoch: 25 Average loss: 405.4237 Accuracy: 0.96
# ====> Epoch: 25 ID Test set loss: 384.3204 Accuracy: 0.96
# ====> Epoch: 25 OD Test set loss: 597.3580 Accuracy: 0.16
# ====> Epoch: 25 Average loss: 344.6713 Accuracy: 0.96
# ====> Epoch: 25 ID Test set loss: 393.1003 Accuracy: 0.92
# ====> Epoch: 25 OD Test set loss: 534.1329 Accuracy: 0.28
# ====> Epoch: 25 Average loss: 362.7924 Accuracy: 1.00
# ====> Epoch: 25 ID Test set loss: 365.2491 Accuracy: 0.96
# ====> Epoch: 25 OD Test set loss: 509.0876 Accuracy: 0.28
# ====> Epoch: 25 Average loss: 390.0561 Accuracy: 0.92
# ====> Epoch: 25 ID Test set loss: 422.2671 Accuracy: 0.88
# ====> Epoch: 25 OD Test set loss: 465.7984 Accuracy: 0.40
# ====> Epoch: 25 Average loss: 363.9272 Accuracy: 0.96
# ====> Epoch: 25 ID Test set loss: 349.0005 Accuracy: 1.00
# ====> Epoch: 25 OD Test set loss: 514.5740 Accuracy: 0.24
# ====> Epoch: 25 Average loss: 352.3223 Accuracy: 1.00
# ====> Epoch: 25 ID Test set loss: 357.3474 Accuracy: 1.00
# ====> Epoch: 25 OD Test set loss: 516.3915 Accuracy: 0.28
# ====> Epoch: 26 Average loss: 381.9833 Accuracy: 0.96
# ====> Epoch: 26 ID Test set loss: 356.8381 Accuracy: 1.00
# ====> Epoch: 26 OD Test set loss: 541.6123 Accuracy: 0.20
# ====> Epoch: 26 Average loss: 369.0178 Accuracy: 1.00
# ====> Epoch: 26 ID Test set loss: 351.8113 Accuracy: 1.00
# ====> Epoch: 26 OD Test set loss: 530.7496 Accuracy: 0.36
# ====> Epoch: 26 Average loss: 373.1871 Accuracy: 1.00
# ====> Epoch: 26 ID Test set loss: 349.0356 Accuracy: 0.96
# ====> Epoch: 26 OD Test set loss: 540.3574 Accuracy: 0.20
# ====> Epoch: 26 Average loss: 321.2732 Accuracy: 1.00
# ====> Epoch: 26 ID Test set loss: 363.2603 Accuracy: 0.96
# ====> Epoch: 26 OD Test set loss: 574.6772 Accuracy: 0.20
# ====> Epoch: 26 Average loss: 319.7624 Accuracy: 1.00
# ====> Epoch: 26 ID Test set loss: 332.6004 Accuracy: 0.92
# ====> Epoch: 26 OD Test set loss: 475.1053 Accuracy: 0.32
# ====> Epoch: 26 Average loss: 379.3680 Accuracy: 1.00
# ====> Epoch: 26 ID Test set loss: 420.1049 Accuracy: 0.96
# ====> Epoch: 26 OD Test set loss: 549.5164 Accuracy: 0.24
# ====> Epoch: 26 Average loss: 397.7444 Accuracy: 1.00
# ====> Epoch: 26 ID Test set loss: 376.6130 Accuracy: 1.00
# ====> Epoch: 26 OD Test set loss: 508.1945 Accuracy: 0.28
# ====> Epoch: 26 Average loss: 310.2042 Accuracy: 0.96
# ====> Epoch: 26 ID Test set loss: 323.0972 Accuracy: 1.00
# ====> Epoch: 26 OD Test set loss: 485.6087 Accuracy: 0.32
# ====> Epoch: 26 Average loss: 358.5225 Accuracy: 1.00
# ====> Epoch: 26 ID Test set loss: 341.5546 Accuracy: 0.96
# ====> Epoch: 26 OD Test set loss: 479.1470 Accuracy: 0.36
# ====> Epoch: 26 Average loss: 419.0840 Accuracy: 1.00
# ====> Epoch: 26 ID Test set loss: 367.2149 Accuracy: 1.00
# ====> Epoch: 26 OD Test set loss: 496.6976 Accuracy: 0.44
# ====> Epoch: 26 Average loss: 382.4085 Accuracy: 0.92
# ====> Epoch: 26 ID Test set loss: 346.4973 Accuracy: 1.00
# ====> Epoch: 26 OD Test set loss: 495.1268 Accuracy: 0.24
# ====> Epoch: 27 Average loss: 437.7741 Accuracy: 0.60
# ====> Epoch: 27 ID Test set loss: 485.0473 Accuracy: 0.64
# ====> Epoch: 27 OD Test set loss: 681.0267 Accuracy: 0.16
# ====> Epoch: 27 Average loss: 408.6864 Accuracy: 1.00
# ====> Epoch: 27 ID Test set loss: 439.2527 Accuracy: 0.88
# ====> Epoch: 27 OD Test set loss: 567.3850 Accuracy: 0.36
# ====> Epoch: 27 Average loss: 389.6037 Accuracy: 0.96
# ====> Epoch: 27 ID Test set loss: 388.8473 Accuracy: 0.88
# ====> Epoch: 27 OD Test set loss: 588.7589 Accuracy: 0.24
# ====> Epoch: 27 Average loss: 403.6656 Accuracy: 0.88
# ====> Epoch: 27 ID Test set loss: 388.1537 Accuracy: 0.96
# ====> Epoch: 27 OD Test set loss: 573.0410 Accuracy: 0.40
# ====> Epoch: 27 Average loss: 394.5583 Accuracy: 1.00
# ====> Epoch: 27 ID Test set loss: 374.0393 Accuracy: 1.00
# ====> Epoch: 27 OD Test set loss: 518.5202 Accuracy: 0.36
# ====> Epoch: 27 Average loss: 356.1253 Accuracy: 1.00
# ====> Epoch: 27 ID Test set loss: 373.9641 Accuracy: 0.96
# ====> Epoch: 27 OD Test set loss: 506.5115 Accuracy: 0.32
# ====> Epoch: 27 Average loss: 398.8336 Accuracy: 0.96
# ====> Epoch: 27 ID Test set loss: 345.2113 Accuracy: 1.00
# ====> Epoch: 27 OD Test set loss: 616.5917 Accuracy: 0.12
# ====> Epoch: 27 Average loss: 354.7763 Accuracy: 0.92
# ====> Epoch: 27 ID Test set loss: 373.7491 Accuracy: 0.92
# ====> Epoch: 27 OD Test set loss: 478.3710 Accuracy: 0.40
# ====> Epoch: 27 Average loss: 361.8919 Accuracy: 0.96
# ====> Epoch: 27 ID Test set loss: 382.7075 Accuracy: 1.00
# ====> Epoch: 27 OD Test set loss: 563.4467 Accuracy: 0.24
# ====> Epoch: 27 Average loss: 339.8911 Accuracy: 1.00
# ====> Epoch: 27 ID Test set loss: 387.7856 Accuracy: 0.96
# ====> Epoch: 27 OD Test set loss: 532.6470 Accuracy: 0.36
# ====> Epoch: 27 Average loss: 363.3392 Accuracy: 1.00
# ====> Epoch: 27 ID Test set loss: 342.1184 Accuracy: 0.88
# ====> Epoch: 27 OD Test set loss: 539.7676 Accuracy: 0.16
# ====> Epoch: 28 Average loss: 376.2060 Accuracy: 0.96
# ====> Epoch: 28 ID Test set loss: 354.0123 Accuracy: 1.00
# ====> Epoch: 28 OD Test set loss: 563.3958 Accuracy: 0.32
# ====> Epoch: 28 Average loss: 393.9237 Accuracy: 0.96
# ====> Epoch: 28 ID Test set loss: 393.6923 Accuracy: 1.00
# ====> Epoch: 28 OD Test set loss: 512.8840 Accuracy: 0.32
# ====> Epoch: 28 Average loss: 388.7016 Accuracy: 1.00
# ====> Epoch: 28 ID Test set loss: 347.0106 Accuracy: 1.00
# ====> Epoch: 28 OD Test set loss: 512.2887 Accuracy: 0.32
# ====> Epoch: 28 Average loss: 373.1064 Accuracy: 0.96
# ====> Epoch: 28 ID Test set loss: 386.9673 Accuracy: 0.96
# ====> Epoch: 28 OD Test set loss: 544.5306 Accuracy: 0.36
# ====> Epoch: 28 Average loss: 340.2427 Accuracy: 0.96
# ====> Epoch: 28 ID Test set loss: 406.9880 Accuracy: 0.96
# ====> Epoch: 28 OD Test set loss: 540.6901 Accuracy: 0.28
# ====> Epoch: 28 Average loss: 380.8233 Accuracy: 1.00
# ====> Epoch: 28 ID Test set loss: 354.6208 Accuracy: 1.00
# ====> Epoch: 28 OD Test set loss: 545.4385 Accuracy: 0.32
# ====> Epoch: 28 Average loss: 376.8396 Accuracy: 1.00
# ====> Epoch: 28 ID Test set loss: 363.3883 Accuracy: 1.00
# ====> Epoch: 28 OD Test set loss: 532.0771 Accuracy: 0.28
# ====> Epoch: 28 Average loss: 345.9191 Accuracy: 0.96
# ====> Epoch: 28 ID Test set loss: 373.8495 Accuracy: 1.00
# ====> Epoch: 28 OD Test set loss: 477.0488 Accuracy: 0.44
# ====> Epoch: 28 Average loss: 340.6984 Accuracy: 0.96
# ====> Epoch: 28 ID Test set loss: 370.3995 Accuracy: 1.00
# ====> Epoch: 28 OD Test set loss: 545.1513 Accuracy: 0.28
# ====> Epoch: 28 Average loss: 332.8064 Accuracy: 1.00
# ====> Epoch: 28 ID Test set loss: 367.9310 Accuracy: 1.00
# ====> Epoch: 28 OD Test set loss: 506.7884 Accuracy: 0.48
# ====> Epoch: 28 Average loss: 358.4691 Accuracy: 0.96
# ====> Epoch: 28 ID Test set loss: 366.3485 Accuracy: 1.00
# ====> Epoch: 28 OD Test set loss: 492.1574 Accuracy: 0.36

# %%
torch.save(model.state_dict(), model._get_name())

# %%
from google.colab import files

files.download(model._get_name())

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b0452f87-8d2a-48e1-a375-88e448ef220a" name="files[]" multiple disabled />
#      <output id="result-b0452f87-8d2a-48e1-a375-88e448ef220a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ivb2_net to ivb2_net
# {'ivb2_net': b'\x80\x02\x8a\nl\xfc\x9cF\xf9 j\xa8P\x19.\x80\x02M\xe9\x03.\x80\x02}q\x00(X\x10\x00\x00\x00protocol_versionq\x01M\xe9\x03X\r\x00\x00\x00little_endianq\x02\x88X\n\x00\x00\x00type_sizesq\x03}q\x04(X\x05\x00\x00\x00shortq\x05K\x02X\x03\x00\x00\x00intq\x06K\x04X\x04\x00\x00\x00longq\x07K\x04uu.\x80\x02ccollections\nOrderedDict\nq\x00)Rq\x01(X\x0e\x00\x00\x00conv1.0.weightq\x02ctorch._utils\n_rebuild_tensor_v2\nq\x03((X\x07\x00\x00\x00storageq\x04ctorch\nFloatStorage\nq\x05X\x08\x00\x00\x0040656768q\x06X\x06\x00\x00\x00cuda:0q\x07M`\x03Ntq\x08QK\x00(K K\x03K\x03K\x03tq\t(K\x1bK\tK\x03K\x01tq\n\x89h\x00)Rq\x0btq\x0cRq\rX\x0c\x00\x00\x00conv1.0.biasq\x0eh\x03((h\x04h\x05X\x08\x00\x00\x0048163648q\x0fX\x06\x00\x00\x00cuda:0q\x10K Ntq\x11QK\x00K \x85q\x12K\x01\x85q\x13\x89h\x00)Rq\x14tq\x15Rq\x16X\x0e\x00\x00\x00conv1.1.weightq\x17h\x03((h\x04h\x05X\x08\x00\x00\x0048176704q\x18X\x06\x00\x00\x00cuda:0q\x19K Ntq\x1aQK\x00K \x85q\x1bK\x01\x85q\x1c\x89h\x00)Rq\x1dtq\x1eRq\x1fX\x0c\x00\x00\x00conv1.1.biasq h\x03((h\x04h\x05X\x08\x00\x00\x0021797024q!X\x06\x00\x00\x00cuda:0q"K Ntq#QK\x00K \x85q$K\x01\x85q%\x89h\x00)Rq&tq\'Rq(X\x14\x00\x00\x00conv1.1.running_meanq)h\x03((h\x04h\x05X\x08\x00\x00\x0021795296q*X\x06\x00\x00\x00cuda:0q+K Ntq,QK\x00K \x85q-K\x01\x85q.\x89h\x00)Rq/tq0Rq1X\x13\x00\x00\x00conv1.1.running_varq2h\x03((h\x04h\x05X\x08\x00\x00\x0047635168q3X\x06\x00\x00\x00cuda:0q4K Ntq5QK\x00K \x85q6K\x01\x85q7\x89h\x00)Rq8tq9Rq:X\x1b\x00\x00\x00conv1.1.num_batches_trackedq;h\x03((h\x04ctorch\nLongStorage\nq<X\n\x00\x00\x001697236960q=X\x06\x00\x00\x00cuda:0q>K\x01Ntq?QK\x00))\x89h\x00)Rq@tqARqBX\x0e\x00\x00\x00conv2.0.weightqCh\x03((h\x04h\x05X\x08\x00\x00\x0040652736qDX\x06\x00\x00\x00cuda:0qEM\x00$NtqFQK\x00(K K K\x03K\x03tqG(M \x01K\tK\x03K\x01tqH\x89h\x00)RqItqJRqKX\x0c\x00\x00\x00conv2.0.biasqLh\x03((h\x04h\x05X\x08\x00\x00\x0040648800qMX\x06\x00\x00\x00cuda:0qNK NtqOQK\x00K \x85qPK\x01\x85qQ\x89h\x00)RqRtqSRqTX\x0e\x00\x00\x00conv2.1.weightqUh\x03((h\x04h\x05X\x08\x00\x00\x0047634688qVX\x06\x00\x00\x00cuda:0qWK NtqXQK\x00K \x85qYK\x01\x85qZ\x89h\x00)Rq[tq\\Rq]X\x0c\x00\x00\x00conv2.1.biasq^h\x03((h\x04h\x05X\x08\x00\x00\x0047634880q_X\x06\x00\x00\x00cuda:0q`K NtqaQK\x00K \x85qbK\x01\x85qc\x89h\x00)RqdtqeRqfX\x14\x00\x00\x00conv2.1.running_meanqgh\x03((h\x04h\x05X\x08\x00\x00\x0047633920qhX\x06\x00\x00\x00cuda:0qiK NtqjQK\x00K \x85qkK\x01\x85ql\x89h\x00)RqmtqnRqoX\x13\x00\x00\x00conv2.1.running_varqph\x03((h\x04h\x05X\x08\x00\x00\x0047633728qqX\x06\x00\x00\x00cuda:0qrK NtqsQK\x00K \x85qtK\x01\x85qu\x89h\x00)RqvtqwRqxX\x1b\x00\x00\x00conv2.1.num_batches_trackedqyh\x03((h\x04h<X\n\x00\x00\x001614861344qzX\x06\x00\x00\x00cuda:0q{K\x01Ntq|QK\x00))\x89h\x00)Rq}tq~Rq\x7fX\x0e\x00\x00\x00conv3.0.weightq\x80h\x03((h\x04h\x05X\x08\x00\x00\x0040653408q\x81X\x06\x00\x00\x00cuda:0q\x82M\x00HNtq\x83QK\x00(K@K K\x03K\x03tq\x84(M \x01K\tK\x03K\x01tq\x85\x89h\x00)Rq\x86tq\x87Rq\x88X\x0c\x00\x00\x00conv3.0.biasq\x89h\x03((h\x04h\x05X\x08\x00\x00\x0047634112q\x8aX\x06\x00\x00\x00cuda:0q\x8bK@Ntq\x8cQK\x00K@\x85q\x8dK\x01\x85q\x8e\x89h\x00)Rq\x8ftq\x90Rq\x91X\x0e\x00\x00\x00conv3.1.weightq\x92h\x03((h\x04h\x05X\x08\x00\x00\x0040648704q\x93X\x06\x00\x00\x00cuda:0q\x94K@Ntq\x95QK\x00K@\x85q\x96K\x01\x85q\x97\x89h\x00)Rq\x98tq\x99Rq\x9aX\x0c\x00\x00\x00conv3.1.biasq\x9bh\x03((h\x04h\x05X\x08\x00\x00\x0040648896q\x9cX\x06\x00\x00\x00cuda:0q\x9dK@Ntq\x9eQK\x00K@\x85q\x9fK\x01\x85q\xa0\x89h\x00)Rq\xa1tq\xa2Rq\xa3X\x14\x00\x00\x00conv3.1.running_meanq\xa4h\x03((h\x04h\x05X\x08\x00\x00\x0040649184q\xa5X\x06\x00\x00\x00cuda:0q\xa6K@Ntq\xa7QK\x00K@\x85q\xa8K\x01\x85q\xa9\x89h\x00)Rq\xaatq\xabRq\xacX\x13\x00\x00\x00conv3.1.running_varq\xadh\x03((h\x04h\x05X\x08\x00\x00\x0040649760q\xaeX\x06\x00\x00\x00cuda:0q\xafK@Ntq\xb0QK\x00K@\x85q\xb1K\x01\x85q\xb2\x89h\x00)Rq\xb3tq\xb4Rq\xb5X\x1b\x00\x00\x00conv3.1.num_batches_trackedq\xb6h\x03((h\x04h<X\n\x00\x00\x001625926912q\xb7X\x06\x00\x00\x00cuda:0q\xb8K\x01Ntq\xb9QK\x00))\x89h\x00)Rq\xbatq\xbbRq\xbcX ...

# %%
model.load_state_dict(torch.load(model._get_name()))
# Out:
# <All keys matched successfully>

# %%
it=iter(train_loader)
itt=iter(id_test_loader)
ittt=iter(od_test_loader)
data=next(ittt)
x=data[0].float().to(device)/255
label_ind=data[1].to(device)
label=torch.eye(10)[label_ind].to(device)
if model._get_name()=='vb_net' or model._get_name()=='hvb_net':
  recon,logits,kl_loss=model(x,validation=True)
elif model._get_name()=='b_net':
  logits=model(x)

else: 
  recon,logits,kl_loss,recon_loss=model(x,label_ind,validation=True)
dig=random.randint(0,batch_size)
Image.fromarray((data[0][dig].numpy().astype(np.uint8).transpose(1,2,0)))
# Out:
# <PIL.Image.Image image mode=RGB size=28x28 at 0x7F134D3F9320>

# %%
Image.fromarray((recon.detach().to('cpu').numpy()[dig,:,:,:]*255).astype(np.uint8).transpose(1,2,0))
# Out:
# <PIL.Image.Image image mode=RGB size=28x28 at 0x7F134D423860>

# %%
plt.bar(np.array(range(10)),(logits[dig].exp()/(logits[dig].exp().sum())).detach().cpu())
# Out:
# <BarContainer object of 10 artists>

# %%
train_acc[:]=[1.0 if i>1.0 else i for i in train_acc]
fig, ax = plt.subplots(constrained_layout=True)
plt.plot(train_acc,label="Training")
#plt.plot(np.arange(num_epochs)*num_steps,test_acc,label="Validation")
#plt.title("Accuracy: Training")
plt.xlabel("Number of steps")
plt.ylabel("Accuracy")
plt.legend()

plt.show()

# %%
id_test_acc[:]=[1.0 if i>1.0 else i for i in id_test_acc]

fig, ax = plt.subplots(constrained_layout=True)
plt.plot(id_test_acc,label="ID Test")
plt.plot(od_test_acc,label="OD Test")
#plt.title("Accuracy: Testing")
plt.xlabel("Number of steps")
plt.ylabel("Accuracy")
plt.legend()

plt.show()

# %%
fig, ax = plt.subplots(constrained_layout=True)
plt.plot(id_test_loss,label="ID Test")
plt.plot(od_test_loss,label="OD Test")
#plt.title("Loss: Testing")
plt.xlabel("Number of steps")
plt.ylabel("Loss")
plt.legend()

plt.show()

# %%
import csv

with open(model._get_name()+'.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerows(zip(train_acc, id_test_acc,od_test_acc,id_test_loss,od_test_loss))

# %%
from google.colab import files

files.download(model._get_name()+'.csv')

# %%
od_train_loss=[]
od_train_acc=[]

# %%
#beta=1
tau=1
itt=iter(od_test_loader)
for name,param in model.named_parameters():
    if name=='logits.weight' or name=='logits.bias' or name=='discrim_fc.weight' or name=='discrim_fc.bias':
      param.requires_grad=True
      print(name)
    else:
      param.requires_grad=False
optimizer=torch.optim.SGD(model.parameters(),lr=0.0001)
#optimizer=torch.optim.RMSprop(filter(lambda p: p.requires_grad, model.parameters()),lr=1e-3)
for epoch in range(399):
  data=next(itt)
  x,label,pred_lab,recon,logits,acc,loss=train(data,epoch,batch_size)
  print('====> Epoch: {} OD Test set loss: {:.4f} Accuracy: {:.2f} '.format(epoch, loss,acc))
  od_train_loss.append(loss)
  od_train_acc.append(acc)
# Out:
# logits.weight
# logits.bias
# ====> Epoch: 0 OD Test set loss: 767.4743 Accuracy: 0.24
# ====> Epoch: 1 OD Test set loss: 703.2684 Accuracy: 0.32
# ====> Epoch: 2 OD Test set loss: 700.6689 Accuracy: 0.24
# ====> Epoch: 3 OD Test set loss: 739.7883 Accuracy: 0.40
# ====> Epoch: 4 OD Test set loss: 761.9834 Accuracy: 0.20
# ====> Epoch: 5 OD Test set loss: 646.4240 Accuracy: 0.36
# ====> Epoch: 6 OD Test set loss: 745.7664 Accuracy: 0.44
# ====> Epoch: 7 OD Test set loss: 704.5491 Accuracy: 0.32
# ====> Epoch: 8 OD Test set loss: 712.3801 Accuracy: 0.32
# ====> Epoch: 9 OD Test set loss: 681.7268 Accuracy: 0.28
# ====> Epoch: 10 OD Test set loss: 732.4636 Accuracy: 0.24
# ====> Epoch: 11 OD Test set loss: 659.8637 Accuracy: 0.20
# ====> Epoch: 12 OD Test set loss: 687.5526 Accuracy: 0.40
# ====> Epoch: 13 OD Test set loss: 647.7912 Accuracy: 0.32
# ====> Epoch: 14 OD Test set loss: 763.9832 Accuracy: 0.44
# ====> Epoch: 15 OD Test set loss: 630.1395 Accuracy: 0.44
# ====> Epoch: 16 OD Test set loss: 694.7172 Accuracy: 0.28
# ====> Epoch: 17 OD Test set loss: 673.7325 Accuracy: 0.48
# ====> Epoch: 18 OD Test set loss: 704.7539 Accuracy: 0.40
# ====> Epoch: 19 OD Test set loss: 770.2493 Accuracy: 0.44
# ====> Epoch: 20 OD Test set loss: 676.2148 Accuracy: 0.36
# ====> Epoch: 21 OD Test set loss: 701.0776 Accuracy: 0.44
# ====> Epoch: 22 OD Test set loss: 690.4431 Accuracy: 0.32
# ====> Epoch: 23 OD Test set loss: 687.0284 Accuracy: 0.44
# ====> Epoch: 24 OD Test set loss: 650.4946 Accuracy: 0.72
# ====> Epoch: 25 OD Test set loss: 699.4777 Accuracy: 0.32
# ====> Epoch: 26 OD Test set loss: 737.6525 Accuracy: 0.44
# ====> Epoch: 27 OD Test set loss: 703.3328 Accuracy: 0.52
# ====> Epoch: 28 OD Test set loss: 694.0573 Accuracy: 0.44
# ====> Epoch: 29 OD Test set loss: 648.2888 Accuracy: 0.52
# ====> Epoch: 30 OD Test set loss: 644.3276 Accuracy: 0.52
# ====> Epoch: 31 OD Test set loss: 626.2603 Accuracy: 0.52
# ====> Epoch: 32 OD Test set loss: 648.9276 Accuracy: 0.56
# ====> Epoch: 33 OD Test set loss: 643.2562 Accuracy: 0.44
# ====> Epoch: 34 OD Test set loss: 670.1758 Accuracy: 0.40
# ====> Epoch: 35 OD Test set loss: 726.6265 Accuracy: 0.24
# ====> Epoch: 36 OD Test set loss: 753.2497 Accuracy: 0.36
# ====> Epoch: 37 OD Test set loss: 674.5725 Accuracy: 0.36
# ====> Epoch: 38 OD Test set loss: 673.5831 Accuracy: 0.48
# ====> Epoch: 39 OD Test set loss: 628.8524 Accuracy: 0.68
# ====> Epoch: 40 OD Test set loss: 686.0402 Accuracy: 0.56
# ====> Epoch: 41 OD Test set loss: 653.7784 Accuracy: 0.56
# ====> Epoch: 42 OD Test set loss: 728.2781 Accuracy: 0.40
# ====> Epoch: 43 OD Test set loss: 575.5699 Accuracy: 0.56
# ====> Epoch: 44 OD Test set loss: 685.2776 Accuracy: 0.40
# ====> Epoch: 45 OD Test set loss: 665.0478 Accuracy: 0.40
# ====> Epoch: 46 OD Test set loss: 649.1445 Accuracy: 0.44
# ====> Epoch: 47 OD Test set loss: 606.7177 Accuracy: 0.60
# ====> Epoch: 48 OD Test set loss: 705.1034 Accuracy: 0.64
# ====> Epoch: 49 OD Test set loss: 614.2089 Accuracy: 0.44
# ====> Epoch: 50 OD Test set loss: 653.5526 Accuracy: 0.56
# ====> Epoch: 51 OD Test set loss: 596.8810 Accuracy: 0.52
# ====> Epoch: 52 OD Test set loss: 637.7046 Accuracy: 0.56
# ====> Epoch: 53 OD Test set loss: 633.9348 Accuracy: 0.52
# ====> Epoch: 54 OD Test set loss: 612.1384 Accuracy: 0.64
# ====> Epoch: 55 OD Test set loss: 627.7848 Accuracy: 0.40
# ====> Epoch: 56 OD Test set loss: 623.8334 Accuracy: 0.52
# ====> Epoch: 57 OD Test set loss: 613.9924 Accuracy: 0.56
# ====> Epoch: 58 OD Test set loss: 667.8744 Accuracy: 0.52
# ====> Epoch: 59 OD Test set loss: 590.0534 Accuracy: 0.64
# ====> Epoch: 60 OD Test set loss: 666.7871 Accuracy: 0.68
# ====> Epoch: 61 OD Test set loss: 659.8661 Accuracy: 0.44
# ====> Epoch: 62 OD Test set loss: 700.8252 Accuracy: 0.36
# ====> Epoch: 63 OD Test set loss: 555.9096 Accuracy: 0.60
# ====> Epoch: 64 OD Test set loss: 682.4966 Accuracy: 0.80
# ====> Epoch: 65 OD Test set loss: 685.4989 Accuracy: 0.60
# ====> Epoch: 66 OD Test set loss: 606.9210 Accuracy: 0.64
# ====> Epoch: 67 OD Test set loss: 619.4683 Accuracy: 0.52
# ====> Epoch: 68 OD Test set loss: 645.8679 Accuracy: 0.48
# ====> Epoch: 69 OD Test set loss: 640.7573 Accuracy: 0.80
# ====> Epoch: 70 OD Test set loss: 594.7233 Accuracy: 0.76
# ====> Epoch: 71 OD Test set loss: 560.1457 Accuracy: 0.60
# ====> Epoch: 72 OD Test set loss: 653.4288 Accuracy: 0.48
# ====> Epoch: 73 OD Test set loss: 645.6053 Accuracy: 0.64
# ====> Epoch: 74 OD Test set loss: 640.9708 Accuracy: 0.68
# ====> Epoch: 75 OD Test set loss: 659.5461 Accuracy: 0.52
# ====> Epoch: 76 OD Test set loss: 604.0977 Accuracy: 0.56
# ====> Epoch: 77 OD Test set loss: 617.7352 Accuracy: 0.72
# ====> Epoch: 78 OD Test set loss: 667.0280 Accuracy: 0.84
# ====> Epoch: 79 OD Test set loss: 599.0043 Accuracy: 0.60
# ====> Epoch: 80 OD Test set loss: 699.0537 Accuracy: 0.48
# ====> Epoch: 81 OD Test set loss: 701.8596 Accuracy: 0.44
# ====> Epoch: 82 OD Test set loss: 611.2774 Accuracy: 0.52
# ====> Epoch: 83 OD Test set loss: 618.2984 Accuracy: 0.64
# ====> Epoch: 84 OD Test set loss: 644.1084 Accuracy: 0.60
# ====> Epoch: 85 OD Test set loss: 628.0261 Accuracy: 0.56
# ====> Epoch: 86 OD Test set loss: 636.9009 Accuracy: 0.68
# ====> Epoch: 87 OD Test set loss: 658.8652 Accuracy: 0.48
# ====> Epoch: 88 OD Test set loss: 568.3602 Accuracy: 0.64
# ====> Epoch: 89 OD Test set loss: 614.3890 Accuracy: 0.64
# ====> Epoch: 90 OD Test set loss: 723.8522 Accuracy: 0.60
# ====> Epoch: 91 OD Test set loss: 651.8335 Accuracy: 0.52
# ====> Epoch: 92 OD Test set loss: 697.2094 Accuracy: 0.56
# ====> Epoch: 93 OD Test set loss: 656.3563 Accuracy: 0.48
# ====> Epoch: 94 OD Test set loss: 596.1767 Accuracy: 0.60
# ====> Epoch: 95 OD Test set loss: 676.8426 Accuracy: 0.88
# ====> Epoch: 96 OD Test set loss: 610.6253 Accuracy: 0.64
# ====> Epoch: 97 OD Test set loss: 626.1494 Accuracy: 0.84
# ====> Epoch: 98 OD Test set loss: 588.8243 Accuracy: 0.80
# ====> Epoch: 99 OD Test set loss: 677.6431 Accuracy: 0.68
# ====> Epoch: 100 OD Test set loss: 695.9236 Accuracy: 0.52
# ====> Epoch: 101 OD Test set loss: 624.6565 Accuracy: 0.64
# ====> Epoch: 102 OD Test set loss: 680.7398 Accuracy: 0.64
# ====> Epoch: 103 OD Test set loss: 681.7764 Accuracy: 0.56
# ====> Epoch: 104 OD Test set loss: 703.5272 Accuracy: 0.68
# ====> Epoch: 105 OD Test set loss: 585.4808 Accuracy: 0.72
# ====> Epoch: 106 OD Test set loss: 633.6271 Accuracy: 0.56
# ====> Epoch: 107 OD Test set loss: 689.2942 Accuracy: 0.68
# ====> Epoch: 108 OD Test set loss: 642.8111 Accuracy: 0.52
# ====> Epoch: 109 OD Test set loss: 640.7079 Accuracy: 0.76
# ====> Epoch: 110 OD Test set loss: 691.0402 Accuracy: 0.68
# ====> Epoch: 111 OD Test set loss: 645.6570 Accuracy: 0.72
# ====> Epoch: 112 OD Test set loss: 577.0839 Accuracy: 0.76
# ====> Epoch: 113 OD Test set loss: 622.4545 Accuracy: 0.72
# ====> Epoch: 114 OD Test set loss: 669.1177 Accuracy: 0.68
# ====> Epoch: 115 OD Test set loss: 617.2160 Accuracy: 0.64
# ====> Epoch: 116 OD Test set loss: 657.5090 Accuracy: 0.68
# ====> Epoch: 117 OD Test set loss: 622.0445 Accuracy: 0.84
# ====> Epoch: 118 OD Test set loss: 578.7932 Accuracy: 0.72
# ====> Epoch: 119 OD Test set loss: 614.8321 Accuracy: 0.68
# ====> Epoch: 120 OD Test set loss: 591.1252 Accuracy: 0.32
# ====> Epoch: 121 OD Test set loss: 651.6184 Accuracy: 0.48
# ====> Epoch: 122 OD Test set loss: 688.6989 Accuracy: 0.88
# ====> Epoch: 123 OD Test set loss: 566.0604 Accuracy: 0.84
# ====> Epoch: 124 OD Test set loss: 684.6144 Accuracy: 0.76
# ====> Epoch: 125 OD Test set loss: 581.3243 Accuracy: 0.56
# ====> Epoch: 126 OD Test set loss: 621.3789 Accuracy: 0.72
# ====> Epoch: 127 OD Test set loss: 657.0993 Accuracy: 0.76
# ====> Epoch: 128 OD Test set loss: 632.4460 Accuracy: 0.72
# ====> Epoch: 129 OD Test set loss: 653.1486 Accuracy: 0.84
# ====> Epoch: 130 OD Test set loss: 717.8160 Accuracy: 0.76
# ====> Epoch: 131 OD Test set loss: 650.4005 Accuracy: 0.60
# ====> Epoch: 132 OD Test set loss: 659.7646 Accuracy: 0.64
# ====> Epoch: 133 OD Test set loss: 644.3528 Accuracy: 0.88
# ====> Epoch: 134 OD Test set loss: 663.2685 Accuracy: 0.76
# ====> Epoch: 135 OD Test set loss: 629.9800 Accuracy: 0.64
# ====> Epoch: 136 OD Test set loss: 696.3420 Accuracy: 0.52
# ====> Epoch: 137 OD Test set loss: 614.2917 Accuracy: 0.44
# ====> Epoch: 138 OD Test set loss: 615.1190 Accuracy: 0.76
# ====> Epoch: 139 OD Test set loss: 669.7820 Accuracy: 0.68
# ====> Epoch: 140 OD Test set loss: 640.6342 Accuracy: 0.68
# ====> Epoch: 141 OD Test set loss: 631.3691 Accuracy: 0.80
# ====> Epoch: 142 OD Test set loss: 602.5813 Accuracy: 0.44
# ====> Epoch: 143 OD Test set loss: 631.6519 Accuracy: 0.84
# ====> Epoch: 144 OD Test set loss: 665.5224 Accuracy: 0.72
# ====> Epoch: 145 OD Test set loss: 670.1100 Accuracy: 0.64
# ====> Epoch: 146 OD Test set loss: 632.5344 Accuracy: 0.64
# ====> Epoch: 147 OD Test set loss: 688.3315 Accuracy: 0.48
# ====> Epoch: 148 OD Test set loss: 630.7057 Accuracy: 0.68
# ====> Epoch: 149 OD Test set loss: 548.4929 Accuracy: 0.48
# ====> Epoch: 150 OD Test set loss: 642.9009 Accuracy: 0.64
# ====> Epoch: 151 OD Test set loss: 686.6306 Accuracy: 0.72
# ====> Epoch: 152 OD Test set loss: 617.1762 Accuracy: 0.56
# ====> Epoch: 153 OD Test set loss: 548.0875 Accuracy: 0.68
# ====> Epoch: 154 OD Test set loss: 628.6127 Accuracy: 0.72
# ====> Epoch: 155 OD Test set loss: 622.9800 Accuracy: 0.76
# ====> Epoch: 156 OD Test set loss: 708.0715 Accuracy: 0.60
# ====> Epoch: 157 OD Test set loss: 697.3452 Accuracy: 0.80
# ====> Epoch: 158 OD Test set loss: 589.9541 Accuracy: 0.76
# ====> Epoch: 159 OD Test set loss: 662.8745 Accuracy: 0.68
# ====> Epoch: 160 OD Test set loss: 655.2911 Accuracy: 0.68
# ====> Epoch: 161 OD Test set loss: 623.0073 Accuracy: 0.88
# ====> Epoch: 162 OD Test set loss: 655.1454 Accuracy: 0.76
# ====> Epoch: 163 OD Test set loss: 558.3420 Accuracy: 0.64
# ====> Epoch: 164 OD Test set loss: 577.5488 Accuracy: 0.64
# ====> Epoch: 165 OD Test set loss: 630.0498 Accuracy: 0.72
# ====> Epoch: 166 OD Test set loss: 695.7709 Accuracy: 0.60
# ====> Epoch: 167 OD Test set loss: 576.3906 Accuracy: 0.64
# ====> Epoch: 168 OD Test set loss: 619.5941 Accuracy: 0.64
# ====> Epoch: 169 OD Test set loss: 626.6340 Accuracy: 0.56
# ====> Epoch: 170 OD Test set loss: 701.9306 Accuracy: 0.68
# ====> Epoch: 171 OD Test set loss: 601.5930 Accuracy: 0.76
# ====> Epoch: 172 OD Test set loss: 599.9206 Accuracy: 0.76
# ====> Epoch: 173 OD Test set loss: 554.2430 Accuracy: 0.84
# ====> Epoch: 174 OD Test set loss: 622.4744 Accuracy: 0.84
# ====> Epoch: 175 OD Test set loss: 650.8669 Accuracy: 0.64
# ====> Epoch: 176 OD Test set loss: 657.9067 Accuracy: 0.60
# ====> Epoch: 177 OD Test set loss: 606.0289 Accuracy: 0.64
# ====> Epoch: 178 OD Test set loss: 694.6142 Accuracy: 0.80
# ====> Epoch: 179 OD Test set loss: 630.5145 Accuracy: 0.68
# ====> Epoch: 180 OD Test set loss: 597.3032 Accuracy: 0.84
# ====> Epoch: 181 OD Test set loss: 657.1895 Accuracy: 0.76
# ====> Epoch: 182 OD Test set loss: 608.1929 Accuracy: 0.64
# ====> Epoch: 183 OD Test set loss: 682.4359 Accuracy: 0.72
# ====> Epoch: 184 OD Test set loss: 630.0905 Accuracy: 0.76
# ====> Epoch: 185 OD Test set loss: 639.3068 Accuracy: 0.76
# ====> Epoch: 186 OD Test set loss: 594.3324 Accuracy: 0.80
# ====> Epoch: 187 OD Test set loss: 633.5658 Accuracy: 0.88
# ====> Epoch: 188 OD Test set loss: 687.3849 Accuracy: 0.68
# ====> Epoch: 189 OD Test set loss: 634.7493 Accuracy: 0.80
# ====> Epoch: 190 OD Test set loss: 590.6606 Accuracy: 0.72
# ====> Epoch: 191 OD Test set loss: 632.7783 Accuracy: 0.40
# ====> Epoch: 192 OD Test set loss: 657.4300 Accuracy: 0.80
# ====> Epoch: 193 OD Test set loss: 641.6361 Accuracy: 0.72
# ====> Epoch: 194 OD Test set loss: 677.3516 Accuracy: 0.80
# ====> Epoch: 195 OD Test set loss: 611.1052 Accuracy: 0.72
# ====> Epoch: 196 OD Test set loss: 608.4079 Accuracy: 0.72
# ====> Epoch: 197 OD Test set loss: 638.6978 Accuracy: 0.72
# ====> Epoch: 198 OD Test set loss: 608.5957 Accuracy: 0.88
# ====> Epoch: 199 OD Test set loss: 623.9197 Accuracy: 0.80
# ====> Epoch: 200 OD Test set loss: 642.0258 Accuracy: 0.64
# ====> Epoch: 201 OD Test set loss: 569.9881 Accuracy: 0.84
# ====> Epoch: 202 OD Test set loss: 600.8679 Accuracy: 0.92
# ====> Epoch: 203 OD Test set loss: 573.9760 Accuracy: 0.72
# ====> Epoch: 204 OD Test set loss: 621.8965 Accuracy: 0.68
# ====> Epoch: 205 OD Test set loss: 573.6925 Accuracy: 0.80
# ====> Epoch: 206 OD Test set loss: 617.1113 Accuracy: 0.80
# ====> Epoch: 207 OD Test set loss: 664.4189 Accuracy: 0.60
# ====> Epoch: 208 OD Test set loss: 561.4791 Accuracy: 0.76
# ====> Epoch: 209 OD Test set loss: 638.4789 Accuracy: 0.76
# ====> Epoch: 210 OD Test set loss: 667.4858 Accuracy: 0.56
# ====> Epoch: 211 OD Test set loss: 683.2214 Accuracy: 0.64
# ====> Epoch: 212 OD Test set loss: 619.7825 Accuracy: 0.72
# ====> Epoch: 213 OD Test set loss: 635.0090 Accuracy: 0.92
# ====> Epoch: 214 OD Test set loss: 647.2575 Accuracy: 0.72
# ====> Epoch: 215 OD Test set loss: 643.7533 Accuracy: 0.72
# ====> Epoch: 216 OD Test set loss: 618.9033 Accuracy: 0.64
# ====> Epoch: 217 OD Test set loss: 564.2238 Accuracy: 0.84
# ====> Epoch: 218 OD Test set loss: 598.8488 Accuracy: 0.84
# ====> Epoch: 219 OD Test set loss: 674.5637 Accuracy: 0.88
# ====> Epoch: 220 OD Test set loss: 603.0205 Accuracy: 0.68
# ====> Epoch: 221 OD Test set loss: 570.0732 Accuracy: 0.80
# ====> Epoch: 222 OD Test set loss: 582.2404 Accuracy: 0.80
# ====> Epoch: 223 OD Test set loss: 679.6801 Accuracy: 0.76
# ====> Epoch: 224 OD Test set loss: 676.6581 Accuracy: 0.60
# ====> Epoch: 225 OD Test set loss: 622.5048 Accuracy: 0.84
# ====> Epoch: 226 OD Test set loss: 634.1857 Accuracy: 0.80
# ====> Epoch: 227 OD Test set loss: 619.6653 Accuracy: 0.80
# ====> Epoch: 228 OD Test set loss: 638.1778 Accuracy: 0.84
# ====> Epoch: 229 OD Test set loss: 684.5495 Accuracy: 0.68
# ====> Epoch: 230 OD Test set loss: 612.8837 Accuracy: 0.84
# ====> Epoch: 231 OD Test set loss: 570.7612 Accuracy: 0.60
# ====> Epoch: 232 OD Test set loss: 570.2587 Accuracy: 0.72
# ====> Epoch: 233 OD Test set loss: 641.3168 Accuracy: 0.72
# ====> Epoch: 234 OD Test set loss: 604.0998 Accuracy: 0.76
# ====> Epoch: 235 OD Test set loss: 624.6088 Accuracy: 0.84
# ====> Epoch: 236 OD Test set loss: 580.5069 Accuracy: 0.72
# ====> Epoch: 237 OD Test set loss: 703.8451 Accuracy: 0.84
# ====> Epoch: 238 OD Test set loss: 632.6705 Accuracy: 0.76
# ====> Epoch: 239 OD Test set loss: 590.1633 Accuracy: 0.68
# ====> Epoch: 240 OD Test set loss: 618.2517 Accuracy: 0.80
# ====> Epoch: 241 OD Test set loss: 634.8662 Accuracy: 0.88
# ====> Epoch: 242 OD Test set loss: 584.9687 Accuracy: 0.68
# ====> Epoch: 243 OD Test set loss: 778.9114 Accuracy: 0.76
# ====> Epoch: 244 OD Test set loss: 555.0866 Accuracy: 0.80
# ====> Epoch: 245 OD Test set loss: 606.9847 Accuracy: 0.84
# ====> Epoch: 246 OD Test set loss: 630.0782 Accuracy: 0.84
# ====> Epoch: 247 OD Test set loss: 673.1477 Accuracy: 0.92
# ====> Epoch: 248 OD Test set loss: 546.5204 Accuracy: 0.80
# ====> Epoch: 249 OD Test set loss: 737.9138 Accuracy: 0.88
# ====> Epoch: 250 OD Test set loss: 532.1074 Accuracy: 0.84
# ====> Epoch: 251 OD Test set loss: 612.6158 Accuracy: 0.84
# ====> Epoch: 252 OD Test set loss: 580.4221 Accuracy: 0.80
# ====> Epoch: 253 OD Test set loss: 633.5967 Accuracy: 0.68
# ====> Epoch: 254 OD Test set loss: 634.9551 Accuracy: 0.64
# ====> Epoch: 255 OD Test set loss: 589.3322 Accuracy: 0.60
# ====> Epoch: 256 OD Test set loss: 594.1618 Accuracy: 0.84
# ====> Epoch: 257 OD Test set loss: 642.5662 Accuracy: 0.72
# ====> Epoch: 258 OD Test set loss: 656.1900 Accuracy: 0.80
# ====> Epoch: 259 OD Test set loss: 627.1963 Accuracy: 0.80
# ====> Epoch: 260 OD Test set loss: 668.9716 Accuracy: 0.64
# ====> Epoch: 261 OD Test set loss: 585.7402 Accuracy: 0.88
# ====> Epoch: 262 OD Test set loss: 576.1025 Accuracy: 0.72
# ====> Epoch: 263 OD Test set loss: 628.0439 Accuracy: 0.80
# ====> Epoch: 264 OD Test set loss: 621.7869 Accuracy: 0.88
# ====> Epoch: 265 OD Test set loss: 724.9710 Accuracy: 0.76
# ====> Epoch: 266 OD Test set loss: 619.2864 Accuracy: 0.76
# ====> Epoch: 267 OD Test set loss: 595.0675 Accuracy: 0.76
# ====> Epoch: 268 OD Test set loss: 600.2745 Accuracy: 0.84
# ====> Epoch: 269 OD Test set loss: 710.0497 Accuracy: 0.76
# ====> Epoch: 270 OD Test set loss: 671.3941 Accuracy: 0.84
# ====> Epoch: 271 OD Test set loss: 620.4129 Accuracy: 0.76
# ====> Epoch: 272 OD Test set loss: 640.3793 Accuracy: 0.64
# ====> Epoch: 273 OD Test set loss: 659.6063 Accuracy: 0.64
# ====> Epoch: 274 OD Test set loss: 554.6697 Accuracy: 0.80
# ====> Epoch: 275 OD Test set loss: 620.2654 Accuracy: 0.88
# ====> Epoch: 276 OD Test set loss: 619.2133 Accuracy: 0.72
# ====> Epoch: 277 OD Test set loss: 632.3904 Accuracy: 0.76
# ====> Epoch: 278 OD Test set loss: 679.8184 Accuracy: 0.80
# ====> Epoch: 279 OD Test set loss: 618.5190 Accuracy: 0.64
# ====> Epoch: 280 OD Test set loss: 622.6940 Accuracy: 0.92
# ====> Epoch: 281 OD Test set loss: 659.8438 Accuracy: 0.68
# ====> Epoch: 282 OD Test set loss: 601.7295 Accuracy: 0.76
# ====> Epoch: 283 OD Test set loss: 668.4987 Accuracy: 0.76
# ====> Epoch: 284 OD Test set loss: 659.6186 Accuracy: 0.88
# ====> Epoch: 285 OD Test set loss: 582.9617 Accuracy: 0.84
# ====> Epoch: 286 OD Test set loss: 574.9897 Accuracy: 0.80
# ====> Epoch: 287 OD Test set loss: 597.7767 Accuracy: 0.60
# ====> Epoch: 288 OD Test set loss: 626.0634 Accuracy: 0.76
# ====> Epoch: 289 OD Test set loss: 618.1830 Accuracy: 0.68
# ====> Epoch: 290 OD Test set loss: 563.8748 Accuracy: 0.76
# ====> Epoch: 291 OD Test set loss: 608.4303 Accuracy: 0.76
# ====> Epoch: 292 OD Test set loss: 586.8882 Accuracy: 0.76
# ====> Epoch: 293 OD Test set loss: 627.9083 Accuracy: 0.80
# ====> Epoch: 294 OD Test set loss: 566.0472 Accuracy: 0.84
# ====> Epoch: 295 OD Test set loss: 613.4256 Accuracy: 0.88
# ====> Epoch: 296 OD Test set loss: 646.6179 Accuracy: 0.76
# ====> Epoch: 297 OD Test set loss: 585.1663 Accuracy: 0.92
# ====> Epoch: 298 OD Test set loss: 606.1032 Accuracy: 0.72
# ====> Epoch: 299 OD Test set loss: 601.8934 Accuracy: 0.80
# ====> Epoch: 300 OD Test set loss: 647.8491 Accuracy: 0.76
# ====> Epoch: 301 OD Test set loss: 603.2130 Accuracy: 0.72
# ====> Epoch: 302 OD Test set loss: 656.0367 Accuracy: 0.76
# ====> Epoch: 303 OD Test set loss: 600.2243 Accuracy: 0.80
# ====> Epoch: 304 OD Test set loss: 540.8064 Accuracy: 0.84
# ====> Epoch: 305 OD Test set loss: 652.3162 Accuracy: 0.72
# ====> Epoch: 306 OD Test set loss: 630.7600 Accuracy: 0.80
# ====> Epoch: 307 OD Test set loss: 639.0991 Accuracy: 0.80
# ====> Epoch: 308 OD Test set loss: 620.0463 Accuracy: 0.80
# ====> Epoch: 309 OD Test set loss: 592.4812 Accuracy: 0.80
# ====> Epoch: 310 OD Test set loss: 621.9642 Accuracy: 0.76
# ====> Epoch: 311 OD Test set loss: 650.4987 Accuracy: 0.88
# ====> Epoch: 312 OD Test set loss: 658.4640 Accuracy: 0.76
# ====> Epoch: 313 OD Test set loss: 625.6408 Accuracy: 0.84
# ====> Epoch: 314 OD Test set loss: 615.1037 Accuracy: 0.76
# ====> Epoch: 315 OD Test set loss: 569.1851 Accuracy: 0.92
# ====> Epoch: 316 OD Test set loss: 668.4548 Accuracy: 0.72
# ====> Epoch: 317 OD Test set loss: 647.2446 Accuracy: 0.84
# ====> Epoch: 318 OD Test set loss: 682.0190 Accuracy: 0.80
# ====> Epoch: 319 OD Test set loss: 639.9203 Accuracy: 0.84
# ====> Epoch: 320 OD Test set loss: 585.9996 Accuracy: 0.84
# ====> Epoch: 321 OD Test set loss: 601.0353 Accuracy: 0.88
# ====> Epoch: 322 OD Test set loss: 706.4153 Accuracy: 0.84
# ====> Epoch: 323 OD Test set loss: 655.0361 Accuracy: 0.88
# ====> Epoch: 324 OD Test set loss: 620.9304 Accuracy: 0.84
# ====> Epoch: 325 OD Test set loss: 614.1763 Accuracy: 0.72
# ====> Epoch: 326 OD Test set loss: 641.5720 Accuracy: 0.84
# ====> Epoch: 327 OD Test set loss: 594.3583 Accuracy: 0.72
# ====> Epoch: 328 OD Test set loss: 627.2043 Accuracy: 0.80
# ====> Epoch: 329 OD Test set loss: 583.4051 Accuracy: 0.76
# ====> Epoch: 330 OD Test set loss: 663.8994 Accuracy: 0.88
# ====> Epoch: 331 OD Test set loss: 557.0027 Accuracy: 0.92
# ====> Epoch: 332 OD Test set loss: 648.0345 Accuracy: 0.68
# ====> Epoch: 333 OD Test set loss: 719.3664 Accuracy: 0.72
# ====> Epoch: 334 OD Test set loss: 652.0637 Accuracy: 0.76
# ====> Epoch: 335 OD Test set loss: 749.6003 Accuracy: 0.72
# ====> Epoch: 336 OD Test set loss: 585.5693 Accuracy: 0.60
# ====> Epoch: 337 OD Test set loss: 595.7689 Accuracy: 0.72
# ====> Epoch: 338 OD Test set loss: 646.8130 Accuracy: 0.80
# ====> Epoch: 339 OD Test set loss: 571.3715 Accuracy: 0.88
# ====> Epoch: 340 OD Test set loss: 591.3351 Accuracy: 0.88
# ====> Epoch: 341 OD Test set loss: 582.6798 Accuracy: 0.72
# ====> Epoch: 342 OD Test set loss: 671.1091 Accuracy: 0.88
# ====> Epoch: 343 OD Test set loss: 583.6115 Accuracy: 0.72
# ====> Epoch: 344 OD Test set loss: 569.6201 Accuracy: 0.80
# ====> Epoch: 345 OD Test set loss: 625.1226 Accuracy: 0.76
# ====> Epoch: 346 OD Test set loss: 632.0579 Accuracy: 0.68
# ====> Epoch: 347 OD Test set loss: 660.4012 Accuracy: 0.72
# ====> Epoch: 348 OD Test set loss: 634.5510 Accuracy: 0.80
# ====> Epoch: 349 OD Test set loss: 609.4943 Accuracy: 0.88
# ====> Epoch: 350 OD Test set loss: 596.8838 Accuracy: 0.88
# ====> Epoch: 351 OD Test set loss: 633.4588 Accuracy: 0.60
# ====> Epoch: 352 OD Test set loss: 603.3163 Accuracy: 0.72
# ====> Epoch: 353 OD Test set loss: 638.8563 Accuracy: 0.68
# ====> Epoch: 354 OD Test set loss: 727.4575 Accuracy: 0.80
# ====> Epoch: 355 OD Test set loss: 601.5252 Accuracy: 0.72
# ====> Epoch: 356 OD Test set loss: 554.8296 Accuracy: 0.76
# ====> Epoch: 357 OD Test set loss: 621.8636 Accuracy: 0.68
# ====> Epoch: 358 OD Test set loss: 597.6844 Accuracy: 0.68
# ====> Epoch: 359 OD Test set loss: 573.6119 Accuracy: 0.80
# ====> Epoch: 360 OD Test set loss: 685.0723 Accuracy: 0.76
# ====> Epoch: 361 OD Test set loss: 642.9517 Accuracy: 0.80
# ====> Epoch: 362 OD Test set loss: 595.2829 Accuracy: 0.80
# ====> Epoch: 363 OD Test set loss: 639.8997 Accuracy: 0.84
# ====> Epoch: 364 OD Test set loss: 607.7064 Accuracy: 0.72
# ====> Epoch: 365 OD Test set loss: 671.7924 Accuracy: 0.68
# ====> Epoch: 366 OD Test set loss: 632.5034 Accuracy: 0.72
# ====> Epoch: 367 OD Test set loss: 615.1215 Accuracy: 0.80
# ====> Epoch: 368 OD Test set loss: 591.9409 Accuracy: 0.72
# ====> Epoch: 369 OD Test set loss: 595.5787 Accuracy: 0.76
# ====> Epoch: 370 OD Test set loss: 629.5645 Accuracy: 0.76
# ====> Epoch: 371 OD Test set loss: 617.9457 Accuracy: 0.72
# ====> Epoch: 372 OD Test set loss: 647.6658 Accuracy: 0.76
# ====> Epoch: 373 OD Test set loss: 663.3044 Accuracy: 0.88
# ====> Epoch: 374 OD Test set loss: 688.7536 Accuracy: 0.52
# ====> Epoch: 375 OD Test set loss: 620.6215 Accuracy: 0.68
# ====> Epoch: 376 OD Test set loss: 622.9073 Accuracy: 0.92
# ====> Epoch: 377 OD Test set loss: 670.7964 Accuracy: 0.84
# ====> Epoch: 378 OD Test set loss: 572.2172 Accuracy: 0.80
# ====> Epoch: 379 OD Test set loss: 589.3286 Accuracy: 0.80
# ====> Epoch: 380 OD Test set loss: 658.6050 Accuracy: 0.64
# ====> Epoch: 381 OD Test set loss: 645.0118 Accuracy: 0.80
# ====> Epoch: 382 OD Test set loss: 680.3490 Accuracy: 0.88
# ====> Epoch: 383 OD Test set loss: 624.5961 Accuracy: 0.80
# ====> Epoch: 384 OD Test set loss: 607.4432 Accuracy: 0.80
# ====> Epoch: 385 OD Test set loss: 674.6233 Accuracy: 0.72
# ====> Epoch: 386 OD Test set loss: 599.4782 Accuracy: 0.84
# ====> Epoch: 387 OD Test set loss: 705.1312 Accuracy: 0.88
# ====> Epoch: 388 OD Test set loss: 616.1262 Accuracy: 0.76
# ====> Epoch: 389 OD Test set loss: 669.8541 Accuracy: 0.80
# ====> Epoch: 390 OD Test set loss: 610.6848 Accuracy: 0.84
# ====> Epoch: 391 OD Test set loss: 608.8159 Accuracy: 0.80
# ====> Epoch: 392 OD Test set loss: 628.8415 Accuracy: 0.76
# ====> Epoch: 393 OD Test set loss: 666.8559 Accuracy: 0.84
# ====> Epoch: 394 OD Test set loss: 581.9730 Accuracy: 0.76
# ====> Epoch: 395 OD Test set loss: 612.3887 Accuracy: 0.84
# ====> Epoch: 396 OD Test set loss: 633.2087 Accuracy: 0.64
# ====> Epoch: 397 OD Test set loss: 588.2985 Accuracy: 0.56
# ====> Epoch: 398 OD Test set loss: 581.6401 Accuracy: 0.72

# %%
fig, ax = plt.subplots(constrained_layout=True)
plt.plot(od_train_acc,label="OD Test")
#plt.title("Accuracy: OD Training")
plt.xlabel("Number of steps")
plt.ylabel("Accuracy")
plt.legend()

plt.show()

# %%
#need to fix
class hvb_net(nn.Module):
  def __init__(self,z_dim=32,n_samps=1,im_size=28):
    super(hvb_net,self).__init__()
    self.relu=nn.ReLU()

    self.conv1=nn.Sequential(nn.Conv2d(3,32,3,stride=1,padding=1),
                                     nn.BatchNorm2d(32))
    self.conv1_relu_mp=nn.MaxPool2d(2,return_indices=True)
    self.conv1_size=self.conv1_relu_mp(self.conv1(torch.randn(1,3,im_size,im_size)))[0].size()
    self.z1_mu=nn.Linear(self.conv1_size[1]*(self.conv1_size[2]**2),self.conv1_size[1]*(self.conv1_size[2]**2))
    self.z1_logsigma=nn.Linear(self.conv1_size[1]*(self.conv1_size[2]**2),self.conv1_size[1]*(self.conv1_size[2]**2))
    self.z1_pred=nn.Linear(self.conv1_size[1]*(self.conv1_size[2]**2),10)

    self.conv2=nn.Sequential(nn.Conv2d(32,32,3,1,1),
                                     nn.BatchNorm2d(32))
    self.conv2_relu_mp=nn.MaxPool2d(2,return_indices=True)
    self.conv2_size=self.conv2_relu_mp(self.conv2(torch.randn(1,self.conv1_size[1],self.conv1_size[2],self.conv1_size[3])))[0].size()
    self.z2_mu=nn.Linear(self.conv2_size[1]*(self.conv2_size[2]**2),self.conv2_size[1]*(self.conv2_size[2]**2))
    self.z2_logsigma=nn.Linear(self.conv2_size[1]*(self.conv2_size[2]**2),self.conv2_size[1]*(self.conv2_size[2]**2))
    self.z2_pred=nn.Linear(self.conv2_size[1]*(self.conv2_size[2]**2),20)

    self.conv3=nn.Sequential(nn.Conv2d(32,64,3,1,1),
                                     nn.BatchNorm2d(64))
    self.conv3_relu_mp=nn.MaxPool2d(2,return_indices=True)
    self.conv3_size=self.conv3_relu_mp(self.conv3(torch.randn(1,self.conv2_size[1],self.conv2_size[2],self.conv2_size[3])))[0].size()
    self.z3_mu=nn.Linear(self.conv3_size[1]*(self.conv3_size[2]**2),self.conv3_size[1]*(self.conv3_size[2]**2))
    self.z3_logsigma=nn.Linear(self.conv3_size[1]*(self.conv3_size[2]**2),self.conv3_size[1]*(self.conv3_size[2]**2))
    self.z3_pred=nn.Linear(self.conv3_size[1]*(self.conv3_size[2]**2),30)
    #print(self.conv1_size,self.conv2_size,self.conv3_size)

    self.fc=nn.Sequential(nn.Linear(3*3*64,z_dim),
                          nn.ReLU())
    
    self.z4_mu=nn.Linear(z_dim,z_dim)
    self.z4_logsigma=nn.Linear(z_dim,z_dim)
    self.logits=nn.Linear(z_dim,10)
    #self.softmax=nn.Softmax()

    self.fc2=nn.Linear(z_dim,3*3*64)
    self.bnfc=nn.BatchNorm2d(64)
    
    self.z2d1=nn.Linear(self.conv3_size[1]*(self.conv3_size[2]**2),self.conv3_size[1]*(self.conv3_size[2]**2))
    self.dconv1_unp=nn.Upsample(size=self.conv2_size[2:],mode='nearest')
    self.dconv1=nn.Sequential(nn.Conv2d(64,32,3,1,1),
                              nn.BatchNorm2d(32)
    )

    self.z2d2=nn.Linear(self.conv2_size[1]*(self.conv2_size[2]**2),self.conv2_size[1]*(self.conv2_size[2]**2))
    self.dconv2_unp=nn.Upsample(scale_factor=2,mode='nearest')
    self.dconv2=nn.Sequential(nn.Conv2d(32,32,3,1,1),
                              nn.BatchNorm2d(32)
    )

    self.z2d3=nn.Linear(self.conv1_size[1]*(self.conv1_size[2]**2),self.conv1_size[1]*(self.conv1_size[2]**2))
    self.dconv3_unp=nn.Upsample(scale_factor=2,mode='nearest')
    self.dconv3=nn.Sequential(nn.Conv2d(32,3,3,1,1),
                              #nn.BatchNorm2d(3),
                              nn.Sigmoid())
    
  def forward(self,image,validation=True,beta=1):
    conv1=self.conv1(image)
    max1_size = conv1.size()
    #print(max1_size)
    conv1_relu_mp,indices1=self.conv1_relu_mp(self.relu(conv1))
    
    z1_mu=self.z1_mu(conv1_relu_mp.view(-1,self.conv1_size[1]*(self.conv1_size[2]**2)))
    z1_logsigma=self.z1_logsigma(conv1_relu_mp.view(-1,self.conv1_size[1]*(self.conv1_size[2]**2)))
    if not validation:
      z1_samp=create_z_sample(z1_mu,z1_logsigma)
    else:
      z1_samp=z1_mu


    #conv2=self.conv2(conv1_relu_mp)
    conv2=self.conv2(z1_samp.view(-1,self.conv1_size[1],self.conv1_size[2],self.conv1_size[3]))
    max2_size = conv2.size()
    #print(max2_size)
    conv2_relu_mp,indices2=self.conv2_relu_mp(self.relu(conv2))

    z2_mu=self.z2_mu(conv2_relu_mp.view(-1,self.conv2_size[1]*(self.conv2_size[2]**2)))
    z2_logsigma=self.z2_logsigma(conv2_relu_mp.view(-1,self.conv2_size[1]*(self.conv2_size[2]**2)))
    if not validation:
      z2_samp=create_z_sample(z2_mu,z2_logsigma)
    else:
      z2_samp=z2_mu

    #conv3=self.conv3(conv2_relu_mp)
    conv3=self.conv3(z2_samp.view(-1,self.conv2_size[1],self.conv2_size[2],self.conv2_size[3]))
    max3_size = conv3.size()
    #print(max3_size)
    conv3_relu_mp,indices3=self.conv3_relu_mp(self.relu(conv3))

    z3_mu=self.z3_mu(conv3_relu_mp.view(-1,self.conv3_size[1]*(self.conv3_size[2]**2)))
    z3_logsigma=self.z3_logsigma(conv3_relu_mp.view(-1,self.conv3_size[1]*(self.conv3_size[2]**2)))
    if not validation:
      z3_samp=create_z_sample(z3_mu,z3_logsigma)
    else:
      z3_samp=z3_mu

    fc=self.fc(conv3_relu_mp.view(-1,self.conv3_size[1]*(self.conv3_size[2]**2)))

    z4_mu=self.z4_mu(fc)
    z4_logsigma=self.z4_logsigma(fc)
    if not validation:
      z4_samp=create_z_sample(z4_mu,z4_logsigma)
    else:
      z4_samp=z4_mu
    #logits=self.logits(torch.cat((z4_samp,z3_samp,z2_samp,z1_samp),1))
    logits=self.logits(z4_samp)

    kl_div=beta*kl_div_norm(z4_mu,z4_logsigma,0,0)
    fc2=self.relu(self.fc2(z4_samp))
    z3_pred=self.z3_pred(fc2)
    
    kl_div+=beta*kl_div_norm(z3_mu,z3_logsigma,z3_pred,0)
    fc2=self.relu(fc2)
    #print(fc2.size())

    #dconv1_unp=self.dconv1_unp(fc2,indices3,max3_size)
    z2d1=self.relu(self.z2d1(fc2).view(-1,self.conv3_size[1],self.conv3_size[2],self.conv3_size[3])
    dconv1_unp=self.dconv1_unp(fc2)
    #print(dconv1_unp.size())
    dconv1=self.dconv1(dconv1_unp)
    z2_pred=self.z2_pred(dconv1.view(-1,self.conv2_size[1]*self.conv2_size[2]*self.conv2_size[3]))
    kl_div+=beta*kl_div_norm(z2_mu,z2_logsigma,z2_pred,0)
    dconv1=self.relu(dconv1)

    #dconv2_unp=self.dconv2_unp(dconv1,indices2,max2_size)
    dconv2_unp=self.dconv2_unp(dconv1)
    dconv2=self.dconv2(dconv2_unp)
    z1_pred=self.z1_pred(dconv2.view(-1,self.conv1_size[1]*self.conv1_size[2]*self.conv1_size[3]))
    kl_div+=beta*kl_div_norm(z1_mu,z1_logsigma,z1_pred,0)
    dconv2=self.relu(dconv2)

    #dconv3_unp=self.dconv3_unp(dconv2,indices1,max1_size)
    dconv3_unp=self.dconv3_unp(dconv2)
    dconv3=self.dconv3(dconv3_unp)
    
    return dconv3,logits,kl_div
# Out:
#   File "<ipython-input-53-ecb7adbbd859>", line 121
#     dconv1_unp=self.dconv1_unp(fc2)
#              ^
# SyntaxError: invalid syntax

# %%
class vblt_net(nn.Module):
  def __init__(self):
    super(b_net).__init__()
    
    self.conv1_relu=nn.Sequential(nn.Conv2d(3,32,3,stride=1,padding=1),
                                     nn.BatchNorm2d(32),
                             nn.ReLU())

    self.conv1_l=nn.Sequential(nn.Conv2d(32,32,3,stride=1,padding=1),
                                     nn.BatchNorm2d(32))
    self.conv1_mp=nn.MaxPool2d(2)
    
    self.conv2_relu=nn.Sequential(nn.Conv2d(32,32,3,1,1)
                                     nn.BatchNorm2d(32),
                                     nn.Relu())
    
    self.conv2_l=nn.Sequential(nn.Conv2d(32,32,3,stride=1,padding=1),
                                     nn.BatchNorm2d(32))
    
    self.conv2_mp=nn.MaxPool2d(2)
    
    self.fc=nn.Sequential(nn.Linear(7*7*32,z_dim),nn.ReLU())
    self.z_mu=nn.Linear(z_dim,z_dim)
    self.z_logsigma=nn.Linear(z_dim,z_dim)
    self.logits=nn.Linear(z_dim,10)
    #self.softmax=nn.Softmax()

    self.fc2=nn.Sequential(nn.Linear(z_dim,7*7*32),
                           nn.ReLU())
    
    self.dconv1=nn.Sequential(nn.ConvTranspose2d(32,32,4,2,1),
                              nn.BatchNorm2d(32),
    )
    self.dconv1_relu=nn.ReLU()

    self.dconv2=nn.Sequential(nn.ConvTranspose2d(32,3,4,2,1),
                              nn.BatchNorm2d(3),
                              nn.Sigmoid())

  def forward(image,conv1_l=0,dconv1=0,conv2_l=0,fc2=0):
    #f(x)
    conv1_relu=self.conv1_relu(image)

    conv1_mp=self.conv1_relu_mp(conv1)
    self.conv1_l.state_dict()['0.weight'][:,2,2,:]=0
    error1=conv1-conv1_l+dconv1
    conv1_l=self.conv1_l(conv1)
    conv2=self.conv2(error1)
    self.conv2_l.state_dict()['0.weight'][:,2,2,:]=0
    conv2_l=self.conv2_l(conv2)
    error2=conv2-conv2_l+fc2
    fc=self.fc()
# Out:
#   File "<ipython-input-140-0cb02c86e726>", line 14
#     nn.BatchNorm2d(32),
#      ^
# SyntaxError: invalid syntax

# %%
#load model
from torchvision.models import resnet50

resnet_model = resnet50(pretrained=False, progress=False)
resnet_model.classifier = nn.Sequential(
            nn.Dropout(0.2),
            nn.Linear(resnet_model.fc.out_features, 10),
            nn.Softmax()
        )
resnet_model.loss=
